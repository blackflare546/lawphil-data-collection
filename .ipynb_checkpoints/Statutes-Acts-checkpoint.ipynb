# %%
import os
import requests
import logging
import pandas as pd
import re
from bs4 import BeautifulSoup

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger()

# Base URL for linking
base_url = "https://lawphil.net/statutes/acts/"
start_url = "https://lawphil.net/statutes/acts/acts.html"

# Directory to save the data files
data_dir = "Data/Statutes/Acts"
os.makedirs(data_dir, exist_ok=True)

def fetch_page(url):
    """Fetches the HTML content of a given URL."""
    try:
        response = requests.get(url)
        response.raise_for_status()
        return response.text
    except requests.RequestException as e:
        logger.error(f"Failed to fetch page: {url}. Error: {e}")
        return None

def parse_main_page(html):
    """Parses the main page to find the desired table with the list of acts."""
    soup = BeautifulSoup(html, 'html.parser')
    table = soup.find('table', {'id': 's-menu'})
    links = []
    
    if not table:
        logger.error("No table with id 's-menu' found on the page.")
        return links
    
    # Process rows within the table
    for row in table.find_all('tr')[1:]:  # Skip the header row
        columns = row.find_all('td')
        if len(columns) < 2:
            continue

        number_link = columns[0].find('a')
        title = columns[1].text.strip()
        
        if number_link and number_link['href']:
            link = number_link['href']
            # Only append valid links (not javascript or empty)
            if link.startswith("javascript"):
                logger.warning(f"Skipping invalid javascript link: {link}")
                continue
            full_link = base_url + link
            links.append((full_link, title))
    
    logger.info(f"Found {len(links)} valid links in the table.")
    return links

def parse_act_page(url):
    """Parses the act page to retrieve the Number, Title, and Data."""
    html = fetch_page(url)
    if not html:
        return None, None, None

    soup = BeautifulSoup(html, 'html.parser')
    blockquote = soup.find('blockquote')
    if not blockquote:
        logger.warning(f"No blockquote found on page: {url}")
        return None, None, None

    paragraphs = blockquote.find_all('p')
    if len(paragraphs) < 2:
        logger.warning(f"Insufficient paragraphs in blockquote at: {url}")
        return None, None, None

    # Clean the 'Number' by removing square brackets and extra spaces
    number = paragraphs[0].text.strip()
    number = re.sub(r'[\[\]]', '', number)  # Remove square brackets

    title = paragraphs[1].text.strip()
    data = blockquote.text.strip()
    
    return number, title, data

def save_to_csv(number, title, data):
    """Saves the act information to a CSV file in the data directory."""
    file_path = os.path.join(data_dir, f"{number}.csv")
    df = pd.DataFrame([[number, title, data]], columns=["Number", "Title", "Data"])
    df.to_csv(file_path, index=False, encoding='utf-8')
    logger.info(f"Data saved to {file_path}")

def main():
    main_page_html = fetch_page(start_url)
    if not main_page_html:
        logger.error("Failed to retrieve main page.")
        return

    act_links = parse_main_page(main_page_html)
    for url, title in act_links:
        logger.info(f"Processing URL: {url}")
        number, title, data = parse_act_page(url)
        if number and title and data:
            save_to_csv(number, title, data)
        else:
            logger.warning(f"Skipping due to incomplete data for URL: {url}")

if __name__ == "__main__":
    main()
# Out:
# 2024-11-14 16:16:44,464 - INFO - Found 4334 links in the table.
# 2024-11-14 16:16:44,464 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4275_1935.html
# 2024-11-14 16:16:48,480 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4275, November 14, 1935 .csv
# 2024-11-14 16:16:48,480 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4274_1935.html
# 2024-11-14 16:16:53,738 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4274, November 14, 1935 .csv
# 2024-11-14 16:16:53,739 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4273_1935.html
# 2024-11-14 16:16:57,513 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4273, November 14, 1935 .csv
# 2024-11-14 16:16:57,514 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4272_1935.html
# 2024-11-14 16:17:01,617 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4272, November 14, 1935 .csv
# 2024-11-14 16:17:01,617 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4271_1935.html
# 2024-11-14 16:17:05,417 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4271, November 14, 1935 .csv
# 2024-11-14 16:17:05,418 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4270_1935.html
# 2024-11-14 16:17:10,140 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4270, November 14, 1935 .csv
# 2024-11-14 16:17:10,141 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4269_1935.html
# 2024-11-14 16:17:14,638 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4269, November 08, 1935 .csv
# 2024-11-14 16:17:14,639 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4268_1935.html
# 2024-11-14 16:17:19,011 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4268, November 08, 1935 .csv
# 2024-11-14 16:17:19,012 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4267_1935.html
# 2024-11-14 16:17:22,029 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4267, November 07, 1935 .csv
# 2024-11-14 16:17:22,030 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4266_1935.html
# 2024-11-14 16:17:26,366 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4266, November 07, 1935 .csv
# 2024-11-14 16:17:26,367 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4265_1935.html
# 2024-11-14 16:17:29,452 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4265, November 07, 1935 .csv
# 2024-11-14 16:17:29,453 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4264_1935.html
# 2024-11-14 16:17:32,373 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4264, November 07, 1935 .csv
# 2024-11-14 16:17:32,374 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4263_1935.html
# 2024-11-14 16:17:34,793 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4263, November 07, 1935 .csv
# 2024-11-14 16:17:34,794 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4262_1935.html
# 2024-11-14 16:17:37,812 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4262, November 07, 1935 .csv
# 2024-11-14 16:17:37,813 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4261_1935.html
# 2024-11-14 16:17:40,285 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4261, November 07, 1935 .csv
# 2024-11-14 16:17:40,286 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4260_1935.html
# 2024-11-14 16:17:42,875 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4260, November 06, 1935 .csv
# 2024-11-14 16:17:42,876 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4259_1935.html
# 2024-11-14 16:17:45,755 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4259, November 06, 1935 .csv
# 2024-11-14 16:17:45,756 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4258_1935.html
# 2024-11-14 16:17:47,853 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4258, November 06, 1935 .csv
# 2024-11-14 16:17:47,854 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4257_1935.html
# 2024-11-14 16:17:51,926 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4257, November 06, 1935 .csv
# 2024-11-14 16:17:51,927 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4256_1935.html
# 2024-11-14 16:17:56,167 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4256, November 06, 1935 .csv
# 2024-11-14 16:17:56,168 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4255_1935.html
# 2024-11-14 16:18:02,121 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4255, November 06, 1935 .csv
# 2024-11-14 16:18:02,121 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4254_1935.html
# 2024-11-14 16:18:08,058 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4254, November 06, 1935 .csv
# 2024-11-14 16:18:08,059 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4253_1935.html
# 2024-11-14 16:18:14,214 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4253, November 06, 1935 .csv
# 2024-11-14 16:18:14,215 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4252_1935.html
# 2024-11-14 16:18:18,704 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4252, November 06, 1935 .csv
# 2024-11-14 16:18:18,705 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4251_1935.html
# 2024-11-14 16:18:23,362 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4251, November 06, 1935 .csv
# 2024-11-14 16:18:23,364 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4250_1935.html
# 2024-11-14 16:18:29,701 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4250, November 06, 1935 .csv
# 2024-11-14 16:18:29,702 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4249_1935.html
# 2024-11-14 16:18:36,761 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4249, November 06, 1935 .csv
# 2024-11-14 16:18:36,762 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4248_1935.html
# 2024-11-14 16:18:41,630 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4248, October 31, 1935 .csv
# 2024-11-14 16:18:41,631 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4247_1935.html
# 2024-11-14 16:18:46,489 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4247, October 28, 1935 .csv
# 2024-11-14 16:18:46,490 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4246_1935.html
# 2024-11-14 16:18:52,607 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4246, October 28, 1935 .csv
# 2024-11-14 16:18:52,608 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4245_1935.html
# 2024-11-14 16:18:57,757 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4245, October 14, 1935 .csv
# 2024-11-14 16:18:57,758 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4244_1935.html
# 2024-11-14 16:19:02,982 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4244, October 10, 1935 .csv
# 2024-11-14 16:19:02,983 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4243_1935.html
# 2024-11-14 16:19:08,387 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4243, September 21, 1935 .csv
# 2024-11-14 16:19:08,388 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4242_1935.html
# 2024-11-14 16:19:13,477 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4242, August 26, 1935 .csv
# 2024-11-14 16:19:13,478 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4241_1935.html
# 2024-11-14 16:19:17,638 - INFO - Data saved to Data/Statutes/Acts/ Act No. 4241, August 23, 1935 .csv
# 2024-11-14 16:19:17,639 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4240_1935.html
# 2024-11-14 16:19:21,805 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4240, August 22, 1935 .csv
# 2024-11-14 16:19:21,806 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4239_1935.html
# 2024-11-14 16:19:29,993 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4239, August 22, 1935 .csv
# 2024-11-14 16:19:29,994 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4238_1935.html
# 2024-11-14 16:19:35,591 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4238, August 21, 1935 .csv
# 2024-11-14 16:19:35,592 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4237_1935.html
# 2024-11-14 16:19:44,024 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4237, August 20, 1935 .csv
# 2024-11-14 16:19:44,025 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4236_1935.html
# 2024-11-14 16:19:52,851 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4236, August 20, 1935 .csv
# 2024-11-14 16:19:52,853 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4235_1935.html
# 2024-11-14 16:19:57,837 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4235, August 20, 1935 .csv
# 2024-11-14 16:19:57,838 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4234_1935.html
# 2024-11-14 16:20:02,651 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4234, August 16, 1935 .csv
# 2024-11-14 16:20:02,652 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4233_1935.html
# 2024-11-14 16:20:15,373 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4233, August 16, 1935 .csv
# 2024-11-14 16:20:15,374 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4232_1935.html
# 2024-11-14 16:20:21,096 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4232, August 16, 1935 .csv
# 2024-11-14 16:20:21,096 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4231_1935.html
# 2024-11-14 16:20:26,370 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4231, August 16, 1935 .csv
# 2024-11-14 16:20:26,371 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4230_1935.html
# 2024-11-14 16:20:37,317 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4230, August 16, 1935 .csv
# 2024-11-14 16:20:37,317 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4229_1935.html
# 2024-11-14 16:20:45,459 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4229, August 12, 1935 .csv
# 2024-11-14 16:20:45,459 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4228_1935.html
# 2024-11-14 16:20:50,614 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4228, August 10, 1935 .csv
# 2024-11-14 16:20:50,615 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4227_1935.html
# 2024-11-14 16:20:56,279 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4227, August 09, 1935 .csv
# 2024-11-14 16:20:56,279 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4226_1935.html
# 2024-11-14 16:21:02,263 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4226, August 09, 1935 .csv
# 2024-11-14 16:21:02,264 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4225_1935.html
# 2024-11-14 16:21:09,526 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4225, August 08, 1935 .csv
# 2024-11-14 16:21:09,527 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4224_1935.html
# 2024-11-14 16:21:15,970 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4224, August 07, 1935 .csv
# 2024-11-14 16:21:15,971 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4223_1935.html
# 2024-11-14 16:21:20,489 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4223, August 07, 1935 .csv
# 2024-11-14 16:21:20,490 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4222_1935.html
# 2024-11-14 16:21:25,051 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4222, August 07, 1935 .csv
# 2024-11-14 16:21:25,052 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4221_1935.html
# 2024-11-14 16:21:30,409 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4221, August 07, 1935 .csv
# 2024-11-14 16:21:30,410 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4220_1935.html
# 2024-11-14 16:21:37,386 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4220, August 06, 1935 .csv
# 2024-11-14 16:21:37,388 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4219_1935.html
# 2024-11-14 16:21:45,019 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4219, August 06, 1935 .csv
# 2024-11-14 16:21:45,020 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4218_1935.html
# 2024-11-14 16:21:52,023 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4218, August 06, 1935 .csv
# 2024-11-14 16:21:52,024 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4217_1935.html
# 2024-11-14 16:21:57,423 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4217, August 06, 1935 .csv
# 2024-11-14 16:21:57,424 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4216_1935.html
# 2024-11-14 16:22:02,977 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4216, August 05, 1935 .csv
# 2024-11-14 16:22:02,978 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4215_1935.html
# 2024-11-14 16:22:09,131 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4215, August 05, 1935 .csv
# 2024-11-14 16:22:09,131 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4214_1935.html
# 2024-11-14 16:22:16,208 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4214, August 05, 1935 .csv
# 2024-11-14 16:22:16,209 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4213_1935.html
# 2024-11-14 16:22:20,919 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4213, August 03, 1935 .csv
# 2024-11-14 16:22:20,920 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4212_1935.html
# 2024-11-14 16:22:26,772 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4212, August 02, 1935 .csv
# 2024-11-14 16:22:26,774 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4211_1935.html
# 2024-11-14 16:22:34,653 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4211, August 02, 1935 .csv
# 2024-11-14 16:22:34,654 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4210_1935.html
# 2024-11-14 16:22:43,090 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4210, August 02, 1935 .csv
# 2024-11-14 16:22:43,091 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4209_1935.html
# 2024-11-14 16:22:47,839 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4209, August 01, 1935 .csv
# 2024-11-14 16:22:47,840 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4208_1935.html
# 2024-11-14 16:22:54,611 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4208, August 01, 1935 .csv
# 2024-11-14 16:22:54,611 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4207_1935.html
# 2024-11-14 16:23:01,808 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4207, August 01, 1935 .csv
# 2024-11-14 16:23:01,808 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4206_1935.html
# 2024-11-14 16:23:08,248 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4206, July 30, 1935 .csv
# 2024-11-14 16:23:08,249 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4205_1935.html
# 2024-11-14 16:23:13,662 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4205, July 25, 1935 .csv
# 2024-11-14 16:23:13,662 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4204_1935.html
# 2024-11-14 16:23:18,172 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4204, July 23, 1935 .csv
# 2024-11-14 16:23:18,173 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4203_1935.html
# 2024-11-14 16:23:24,203 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4203, July 23, 1935 .csv
# 2024-11-14 16:23:24,204 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4202_1935.html
# 2024-11-14 16:23:29,655 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4202, June 20, 1935 .csv
# 2024-11-14 16:23:29,656 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4201_1935.html
# 2024-11-14 16:23:34,578 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4201, June 13, 1935 .csv
# 2024-11-14 16:23:34,579 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4200_1935.html
# 2024-11-14 16:23:38,659 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4200, April 08, 1935 .csv
# 2024-11-14 16:23:38,660 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4199_1935.html
# 2024-11-14 16:23:44,877 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4199, March 16, 1935 .csv
# 2024-11-14 16:23:44,877 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4198_1935.html
# 2024-11-14 16:23:50,342 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4198, March 04, 1935 .csv
# 2024-11-14 16:23:50,343 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4197_1935.html
# 2024-11-14 16:23:55,519 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4197, February 12, 1935 .csv
# 2024-11-14 16:23:55,520 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4196_1935.html
# 2024-11-14 16:24:00,471 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4196, February 05, 1935 .csv
# 2024-11-14 16:24:00,472 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4195_1935.html
# 2024-11-14 16:24:04,369 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4195, February 01, 1935 .csv
# 2024-11-14 16:24:04,370 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4194_1934.html
# 2024-11-14 16:24:08,755 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4194, December 08, 1934 .csv
# 2024-11-14 16:24:08,756 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4193_1934.html
# 2024-11-14 16:24:13,679 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4193, December 08, 1934 .csv
# 2024-11-14 16:24:13,680 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4192_1934.html
# 2024-11-14 16:24:18,608 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4192, December 08, 1934 .csv
# 2024-11-14 16:24:18,609 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4191_1934.html
# 2024-11-14 16:24:23,468 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4191, December 08, 1934 .csv
# 2024-11-14 16:24:23,469 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4190_1934.html
# 2024-11-14 16:24:26,889 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4190, December 08, 1934 .csv
# 2024-11-14 16:24:26,889 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4189_1934.html
# 2024-11-14 16:24:31,212 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4189, December 08, 1934 .csv
# 2024-11-14 16:24:31,212 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4188_1934.html
# 2024-11-14 16:24:38,162 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4188, December 08, 1934 .csv
# 2024-11-14 16:24:38,162 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4187_1934.html
# 2024-11-14 16:24:46,325 - INFO - Data saved to Data/Statutes/Acts/ Act No. 4187, December 08, 1934 .csv
# 2024-11-14 16:24:46,326 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4186_1934.html
# 2024-11-14 16:24:54,502 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4186, December 08, 1934 .csv
# 2024-11-14 16:24:54,503 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4185_1934.html
# 2024-11-14 16:24:59,973 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4185, December 07, 1934 .csv
# 2024-11-14 16:24:59,973 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4184_1934.html
# 2024-11-14 16:25:04,971 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4184, December 07, 1934 .csv
# 2024-11-14 16:25:04,972 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4183_1934.html
# 2024-11-14 16:25:10,815 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4183, December 07, 1934 .csv
# 2024-11-14 16:25:10,816 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4182_1934.html
# 2024-11-14 16:25:16,958 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4182, December 07, 1934 .csv
# 2024-11-14 16:25:16,958 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4181_1934.html
# 2024-11-14 16:25:22,674 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4181, December 07, 1934 .csv
# 2024-11-14 16:25:22,675 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4180_1934.html
# 2024-11-14 16:25:39,389 - INFO - Data saved to Data/Statutes/Acts/ Act No. 4180, December 06, 1934 .csv
# 2024-11-14 16:25:39,390 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4179_1934.html
# 2024-11-14 16:25:44,611 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4179, December 06, 1934 .csv
# 2024-11-14 16:25:44,612 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4178_1934.html
# 2024-11-14 16:25:54,354 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4178, December 05, 1934 .csv
# 2024-11-14 16:25:54,355 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4177_1934.html
# 2024-11-14 16:26:00,177 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4177, December 05, 1934 .csv
# 2024-11-14 16:26:00,178 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4176_1934.html
# 2024-11-14 16:26:06,311 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4176, December 05, 1934 .csv
# 2024-11-14 16:26:06,312 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4175_1934.html
# 2024-11-14 16:26:13,992 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4175, December 05, 1934 .csv
# 2024-11-14 16:26:13,993 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4174_1934.html
# 2024-11-14 16:26:20,450 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4174, December 04, 1934 .csv
# 2024-11-14 16:26:20,451 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4173_1934.html
# 2024-11-14 16:26:27,189 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4173, December 04, 1934 .csv
# 2024-11-14 16:26:27,190 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4172_1934.html
# 2024-11-14 16:26:34,288 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4172, December 04, 1934 .csv
# 2024-11-14 16:26:34,289 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4171_1934.html
# 2024-11-14 16:26:41,856 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4171, December 04, 1934 .csv
# 2024-11-14 16:26:41,857 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4170_1934.html
# 2024-11-14 16:26:47,721 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4170, December 03, 1934 .csv
# 2024-11-14 16:26:47,722 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4169_1934.html
# 2024-11-14 16:26:57,703 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4169, December 03, 1934 .csv
# 2024-11-14 16:26:57,704 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4168_1934.html
# 2024-11-14 16:27:04,391 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4168, December 03, 1934 .csv
# 2024-11-14 16:27:04,392 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4167_1934.html
# 2024-11-14 16:27:10,380 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4167, December 03, 1934 .csv
# 2024-11-14 16:27:10,381 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4166_1934.html
# 2024-11-14 16:27:17,032 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4166, December 04, 1934 .csv
# 2024-11-14 16:27:17,033 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4165_1934.html
# 2024-11-14 16:27:23,953 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4165, December 03, 1934 .csv
# 2024-11-14 16:27:23,953 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4164_1934.html
# 2024-11-14 16:27:31,040 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4164, December 01, 1934 .csv
# 2024-11-14 16:27:31,041 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4163_1934.html
# 2024-11-14 16:27:37,744 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4163, December 01, 1934 .csv
# 2024-11-14 16:27:37,745 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4162_1934.html
# 2024-11-14 16:27:43,216 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4162, December 01, 1934 .csv
# 2024-11-14 16:27:43,217 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4161_1934.html
# 2024-11-14 16:28:10,004 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4161, December 01, 1934 .csv
# 2024-11-14 16:28:10,005 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4160_1934.html
# 2024-11-14 16:28:16,183 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4160, December 01, 1934 .csv
# 2024-11-14 16:28:16,184 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4159_1934.html
# 2024-11-14 16:28:26,602 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4159, December 01, 1934 .csv
# 2024-11-14 16:28:26,603 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4158_1934.html
# 2024-11-14 16:28:32,858 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4158, December 01, 1934 .csv
# 2024-11-14 16:28:32,859 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4157_1934.html
# 2024-11-14 16:28:40,073 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4157, December 01, 1934 .csv
# 2024-11-14 16:28:40,074 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4156_1934.html
# 2024-11-14 16:28:47,272 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4156, December 01, 1934 .csv
# 2024-11-14 16:28:47,273 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4155_1934.html
# 2024-11-14 16:28:53,673 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4155, December 01, 1934 .csv
# 2024-11-14 16:28:53,674 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4154_1934.html
# 2024-11-14 16:29:00,913 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4154, December 01, 1934 .csv
# 2024-11-14 16:29:00,913 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4153_1934.html
# 2024-11-14 16:29:08,490 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4153, November 28, 1934 .csv
# 2024-11-14 16:29:08,491 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4152_1934.html
# 2024-11-14 16:29:13,899 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4152, November 28, 1934 .csv
# 2024-11-14 16:29:13,900 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4151_1934.html
# 2024-11-14 16:29:19,553 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4151, November 28, 1934 .csv
# 2024-11-14 16:29:19,554 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4150_1934.html
# 2024-11-14 16:29:38,914 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4150, November 28, 1934 .csv
# 2024-11-14 16:29:38,915 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4149_1934.html
# 2024-11-14 16:29:43,517 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4149, November 28, 1934 .csv
# 2024-11-14 16:29:43,518 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4148_1934.html
# 2024-11-14 16:29:48,536 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4148, November 28, 1934 .csv
# 2024-11-14 16:29:48,537 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4147_1934.html
# 2024-11-14 16:29:54,057 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4147, November 28, 1934 .csv
# 2024-11-14 16:29:54,058 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4146_1934.html
# 2024-11-14 16:30:00,931 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4146, November 26, 1934 .csv
# 2024-11-14 16:30:00,932 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4145_1934.html
# 2024-11-14 16:30:06,808 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4145, November 26, 1934 .csv
# 2024-11-14 16:30:06,809 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4144_1934.html
# 2024-11-14 16:30:12,192 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4144, November 26, 1934 .csv
# 2024-11-14 16:30:12,193 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4143_1934.html
# 2024-11-14 16:30:17,637 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4143, November 26, 1934 .csv
# 2024-11-14 16:30:17,638 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4142_1934.html
# 2024-11-14 16:30:23,028 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4142, November 24, 1934 .csv
# 2024-11-14 16:30:23,029 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4141_1934.html
# 2024-11-14 16:30:30,113 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4141, November 24, 1934 .csv
# 2024-11-14 16:30:30,114 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4140_1934.html
# 2024-11-14 16:30:34,800 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4140, November 24, 1934 .csv
# 2024-11-14 16:30:34,801 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4139_1934.html
# 2024-11-14 16:30:39,371 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4139, November 23, 1934 .csv
# 2024-11-14 16:30:39,372 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4138_1934.html
# 2024-11-14 16:30:47,401 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4138, November 23, 1934 .csv
# 2024-11-14 16:30:47,402 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4137_1934.html
# 2024-11-14 16:30:56,823 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4137, November 22, 1934 .csv
# 2024-11-14 16:30:56,824 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4136_1934.html
# 2024-11-14 16:31:01,125 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4136, November 22, 1934 .csv
# 2024-11-14 16:31:01,125 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4135_1934.html
# 2024-11-14 16:31:07,363 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4135, November 22, 1934 .csv
# 2024-11-14 16:31:07,364 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4134_1934.html
# 2024-11-14 16:31:16,308 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4134, November 22, 1934 .csv
# 2024-11-14 16:31:16,309 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4133_1934.html
# 2024-11-14 16:31:24,886 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4133, November 22, 1934 .csv
# 2024-11-14 16:31:24,887 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4132_1934.html
# 2024-11-14 16:31:29,695 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4132, November 22, 1934 .csv
# 2024-11-14 16:31:29,696 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4131_1934.html
# 2024-11-14 16:31:35,428 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4131, November 22, 1934 .csv
# 2024-11-14 16:31:35,430 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4130_1934.html
# 2024-11-14 16:31:43,613 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4130, October 30, 1934 .csv
# 2024-11-14 16:31:43,614 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4129_1934.html
# 2024-11-14 16:31:50,262 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4129, October 09, 1934 .csv
# 2024-11-14 16:31:50,262 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4128_1934.html
# 2024-11-14 16:31:54,326 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4128, October 05, 1934 .csv
# 2024-11-14 16:31:54,328 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4127_1934.html
# 2024-11-14 16:32:00,421 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4127, August 21, 1934 .csv
# 2024-11-14 16:32:00,422 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4126_1934.html
# 2024-11-14 16:32:06,351 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4126, May 26, 1934 .csv
# 2024-11-14 16:32:06,352 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4125_1934.html
# 2024-11-14 16:32:15,291 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4125, May 26, 1934 .csv
# 2024-11-14 16:32:15,292 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4124_1934.html
# 2024-11-14 16:32:21,977 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4124, February 09, 1934 .csv
# 2024-11-14 16:32:21,978 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4123_1933.html
# 2024-11-14 16:32:26,334 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4123, December 09, 1933 .csv
# 2024-11-14 16:32:26,335 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4122_1933.html
# 2024-11-14 16:32:33,610 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4122, December 09, 1933 .csv
# 2024-11-14 16:32:33,611 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4121_1933.html
# 2024-11-14 16:32:39,484 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4121, December 08, 1933 .csv
# 2024-11-14 16:32:39,485 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4120_1933.html
# 2024-11-14 16:32:45,562 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4120, December 08, 1933 .csv
# 2024-11-14 16:32:45,565 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4119_1933.html
# 2024-11-14 16:32:51,001 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4119, December 08, 1933 .csv
# 2024-11-14 16:32:51,002 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4118_1933.html
# 2024-11-14 16:32:56,736 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4118, December 07, 1933 .csv
# 2024-11-14 16:32:56,736 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4117_1933.html
# 2024-11-14 16:33:02,980 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4117, December 07, 1933 .csv
# 2024-11-14 16:33:02,981 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4116_1933.html
# 2024-11-14 16:33:09,852 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4116, December 07, 1933 .csv
# 2024-11-14 16:33:09,854 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4115_1933.html
# 2024-11-14 16:33:14,323 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4115, December 07, 1933 .csv
# 2024-11-14 16:33:14,324 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4114_1933.html
# 2024-11-14 16:33:18,951 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4114, December 07, 1933 .csv
# 2024-11-14 16:33:18,951 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4113_1933.html
# 2024-11-14 16:33:21,332 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4113, December 07, 1933 .csv
# 2024-11-14 16:33:21,333 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4112_1933.html
# 2024-11-14 16:33:24,713 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4112, December 07, 1933 .csv
# 2024-11-14 16:33:24,713 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4111_1933.html
# 2024-11-14 16:33:27,038 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4111, December 06, 1933 .csv
# 2024-11-14 16:33:27,038 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4110_1933.html
# 2024-11-14 16:33:29,324 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4110, December 06, 1933 .csv
# 2024-11-14 16:33:29,325 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4109_1933.html
# 2024-11-14 16:33:31,725 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4109, December 06, 1933 .csv
# 2024-11-14 16:33:31,726 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4108_1933.html
# 2024-11-14 16:33:36,429 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4108, December 06, 1933 .csv
# 2024-11-14 16:33:36,430 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4107_1933.html
# 2024-11-14 16:33:40,149 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4107, December 06, 1933 .csv
# 2024-11-14 16:33:40,150 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4106_1933.html
# 2024-11-14 16:33:43,235 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4106, December 05, 1933 .csv
# 2024-11-14 16:33:43,235 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4105_1933.html
# 2024-11-14 16:33:45,999 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4105, December 05, 1933 .csv
# 2024-11-14 16:33:46,000 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4104_1933.html
# 2024-11-14 16:33:48,457 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4104, December 05, 1933 .csv
# 2024-11-14 16:33:48,458 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4103_1933.html
# 2024-11-14 16:33:49,680 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4103, December 05, 1933 .csv
# 2024-11-14 16:33:49,681 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4102_1933.html
# 2024-11-14 16:33:51,547 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4102, December 05, 1933 .csv
# 2024-11-14 16:33:51,547 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4101_1933.html
# 2024-11-14 16:33:52,795 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4101, December 01, 1933 .csv
# 2024-11-14 16:33:52,795 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4100_1933.html
# 2024-11-14 16:33:53,772 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4100, November 29, 1933 .csv
# 2024-11-14 16:33:53,773 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4099_1933.html
# 2024-11-14 16:33:54,229 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4099, November 29, 1933 .csv
# 2024-11-14 16:33:54,229 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4098_1933.html
# 2024-11-14 16:33:55,060 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4098, November 29, 1933 .csv
# 2024-11-14 16:33:55,060 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4097_1933.html
# 2024-11-14 16:33:56,326 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4097, November 29, 1933 .csv
# 2024-11-14 16:33:56,327 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4096_1933.html
# 2024-11-14 16:33:57,365 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4096, November 29, 1933 .csv
# 2024-11-14 16:33:57,366 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4095_1933.html
# 2024-11-14 16:33:57,878 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4095, November 29, 1933 .csv
# 2024-11-14 16:33:57,879 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4094_1933.html
# 2024-11-14 16:33:58,155 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4094, November 29, 1933 .csv
# 2024-11-14 16:33:58,156 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4093_1933.html
# 2024-11-14 16:33:58,438 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4093, November 29, 1933 .csv
# 2024-11-14 16:33:58,440 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4092_1933.html
# 2024-11-14 16:33:58,685 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4092, November 29, 1933 .csv
# 2024-11-14 16:33:58,686 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4091_1933.html
# 2024-11-14 16:33:58,955 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4091, November 29, 1933 .csv
# 2024-11-14 16:33:58,957 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4090_1933.html
# 2024-11-14 16:33:59,293 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4090, November 29, 1933 .csv
# 2024-11-14 16:33:59,293 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4089_1933.html
# 2024-11-14 16:33:59,866 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4089, November 29, 1933 .csv
# 2024-11-14 16:33:59,867 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4088_1933.html
# 2024-11-14 16:34:00,226 - INFO - Data saved to Data/Statutes/Acts/ Act No. 4088, November 29, 1933 .csv
# 2024-11-14 16:34:00,227 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4087_1933.html
# 2024-11-14 16:34:00,548 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4087, November 29, 1933 .csv
# 2024-11-14 16:34:00,548 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4086_1933.html
# 2024-11-14 16:34:01,001 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4086, November 29, 1933 .csv
# 2024-11-14 16:34:01,002 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4085_1933.html
# 2024-11-14 16:34:01,272 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4085, November 29, 1933 .csv
# 2024-11-14 16:34:01,273 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4084_1933.html
# 2024-11-14 16:34:01,874 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4084, November 29, 1933 .csv
# 2024-11-14 16:34:01,875 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4083_1933.html
# 2024-11-14 16:34:02,711 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4083, November 29, 1933 .csv
# 2024-11-14 16:34:02,711 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4082_1933.html
# 2024-11-14 16:34:03,716 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4082, November 29, 1933 .csv
# 2024-11-14 16:34:03,716 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4081_1933.html
# 2024-11-14 16:34:05,386 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4081, November 29, 1933 .csv
# 2024-11-14 16:34:05,386 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4080_1933.html
# 2024-11-14 16:34:05,800 - INFO - Data saved to Data/Statutes/Acts/ Act No. 4080, November 29, 1933 .csv
# 2024-11-14 16:34:05,801 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4079_1933.html
# 2024-11-14 16:34:06,123 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4079, November 29, 1933 .csv
# 2024-11-14 16:34:06,124 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4078_1933.html
# 2024-11-14 16:34:06,403 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4078, November 08, 1933 .csv
# 2024-11-14 16:34:06,404 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4077_1933.html
# 2024-11-14 16:34:06,691 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4077, October 27, 1933 .csv
# 2024-11-14 16:34:06,692 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4076_1933.html
# 2024-11-14 16:34:06,945 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4076, October 27, 1933 .csv
# 2024-11-14 16:34:06,946 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4075_1933.html
# 2024-11-14 16:34:07,254 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4075, October 27, 1933 .csv
# 2024-11-14 16:34:07,255 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4074_1933.html
# 2024-11-14 16:34:07,558 - INFO - Data saved to Data/Statutes/Acts/ Act No. 4074, October 19, 1933 .csv
# 2024-11-14 16:34:07,559 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4073_1933.html
# 2024-11-14 16:34:07,815 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4073, October 12, 1933 .csv
# 2024-11-14 16:34:07,816 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4072_1933.html
# 2024-11-14 16:34:08,129 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4072, October 12, 1933 .csv
# 2024-11-14 16:34:08,130 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4071_1933.html
# 2024-11-14 16:34:08,387 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4071, October 12, 1933 .csv
# 2024-11-14 16:34:08,388 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4070_1933.html
# 2024-11-14 16:34:08,629 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4070, October 12, 1933 .csv
# 2024-11-14 16:34:08,630 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4069_1933.html
# 2024-11-14 16:34:08,889 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4069, October 10, 1933 .csv
# 2024-11-14 16:34:08,890 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4068_1933.html
# 2024-11-14 16:34:09,144 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4068, September 11, 1933 .csv
# 2024-11-14 16:34:09,145 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4067_1933.html
# 2024-11-14 16:34:09,425 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4067, September 04, 1933 .csv
# 2024-11-14 16:34:09,426 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4066_1933.html
# 2024-11-14 16:34:09,681 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4066, August 17, 1933 .csv
# 2024-11-14 16:34:09,682 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4065_1933.html
# 2024-11-14 16:34:09,939 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4065, August 07, 1933 .csv
# 2024-11-14 16:34:09,940 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4064_1933.html
# 2024-11-14 16:34:10,248 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4064, April 29, 1933 .csv
# 2024-11-14 16:34:10,249 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4063_1933.html
# 2024-11-14 16:34:10,496 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4063, March 01, 1933 .csv
# 2024-11-14 16:34:10,497 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4062_1933.html
# 2024-11-14 16:34:10,750 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4062, March 01, 1933 .csv
# 2024-11-14 16:34:10,751 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4061_1933.html
# 2024-11-14 16:34:10,998 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4061, March 01, 1933 .csv
# 2024-11-14 16:34:10,999 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4060_1933.html
# 2024-11-14 16:34:11,298 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4060, March 01, 1933 .csv
# 2024-11-14 16:34:11,298 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4059_1933.html
# 2024-11-14 16:34:11,553 - INFO - Data saved to Data/Statutes/Acts/ Act No. 4059, March 01, 1933 .csv
# 2024-11-14 16:34:11,554 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4058_1933.html
# 2024-11-14 16:34:11,801 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4058, March 01, 1933 .csv
# 2024-11-14 16:34:11,801 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4057_1933.html
# 2024-11-14 16:34:12,070 - INFO - Data saved to Data/Statutes/Acts/ Act No. 4057, March 01, 1933 .csv
# 2024-11-14 16:34:12,070 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4056_1933.html
# 2024-11-14 16:34:12,329 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4056, March 01, 1933 .csv
# 2024-11-14 16:34:12,329 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4055_1933.html
# 2024-11-14 16:34:12,638 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4055, February 27, 1933 .csv
# 2024-11-14 16:34:12,639 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4054_1933.html
# 2024-11-14 16:34:12,932 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4054, February 27, 1933 .csv
# 2024-11-14 16:34:12,932 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4053_1933.html
# 2024-11-14 16:34:13,352 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4053, February 24, 1933 .csv
# 2024-11-14 16:34:13,352 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4052_1933.html
# ...
# 2024-11-14 16:40:08,433 - INFO - Data saved to Data/Statutes/Acts/ Act No. 3578, November 27, 1929 .csv
# 2024-11-14 16:40:08,433 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1929/act_3577_1929.html
# 2024-11-14 16:40:08,687 - INFO - Data saved to Data/Statutes/Acts/ Act No. 3577, November 27, 1929 .csv
# 2024-11-14 16:40:08,691 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1929/act_3576_1929.html
# 2024-11-14 16:40:08,975 - INFO - Data saved to Data/Statutes/Acts/ Act No. 3576, November 27, 1929 .csv
# 2024-11-14 16:40:08,976 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1929/act_3575_1929.html
# 2024-11-14 16:40:09,261 - INFO - Data saved to Data/Statutes/Acts/ Act No. 3575, November 26, 1929 .csv
# 2024-11-14 16:40:09,261 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1929/act_3574_1929.html
# 2024-11-14 16:40:09,508 - INFO - Data saved to Data/Statutes/Acts/ Act No. 3574, November 26, 1929 .csv
# 2024-11-14 16:40:09,509 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1929/act_3573_1929.html
# 2024-11-14 16:40:09,794 - INFO - Data saved to Data/Statutes/Acts/ Act No. 3573, November 26, 1929 .csv
# 2024-11-14 16:40:09,794 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1929/act_3572_1929.html
# 2024-11-14 16:40:10,072 - INFO - Data saved to Data/Statutes/Acts/ Act No. 3572, November 26, 1929 .csv
# 2024-11-14 16:40:10,073 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1929/act_3571_1929.html
# 2024-11-14 16:40:10,375 - INFO - Data saved to Data/Statutes/Acts/ Act No. 3571, November 26, 1929 .csv
# 2024-11-14 16:40:10,376 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1929/act_3570_1929.html
# 2024-11-14 16:40:10,664 - INFO - Data saved to Data/Statutes/Acts/ Act No. 3570, November 26, 1929 .csv
# 2024-11-14 16:40:10,665 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1929/act_3569_1929.html
# 2024-11-14 16:40:11,321 - INFO - Data saved to Data/Statutes/Acts/ Act No. 3569, November 26, 1929 .csv
# 2024-11-14 16:40:11,322 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1929/act_3568_1929.html
# 2024-11-14 16:40:12,229 - INFO - Data saved to Data/Statutes/Acts/ Act No. 3568, November 26, 1929 .csv
# 2024-11-14 16:40:12,230 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1929/act_3567_1929.html
# 2024-11-14 16:40:12,516 - INFO - Data saved to Data/Statutes/Acts/ Act No. 3567, November 26, 1929 .csv
# 2024-11-14 16:40:12,517 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1929/act_3566_1929.html
# 2024-11-14 16:40:12,781 - INFO - Data saved to Data/Statutes/Acts/ Act No. 3566, November 26, 1929 .csv
# 2024-11-14 16:40:12,782 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1929/act_3565_1929.html
# 2024-11-14 16:40:13,070 - INFO - Data saved to Data/Statutes/Acts/ Act No. 3565, November 26, 1929 .csv
# 2024-11-14 16:40:13,070 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1929/act_3564_1929.html
# 2024-11-14 16:40:13,325 - INFO - Data saved to Data/Statutes/Acts/ Act No. 3564, November 26, 1929 .csv
# 2024-11-14 16:40:13,325 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1929/act_3563_1929.html
# 2024-11-14 16:40:13,654 - INFO - Data saved to Data/Statutes/Acts/ Act No. 3563, November 26, 1929 .csv
# 2024-11-14 16:40:13,654 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1929/act_3562_1929.html
# 2024-11-14 16:40:15,309 - INFO - Data saved to Data/Statutes/Acts/ Act No. 3562, November 26, 1929 .csv
# 2024-11-14 16:40:15,309 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1929/act_3561_1929.html
# 2024-11-14 16:40:15,578 - INFO - Data saved to Data/Statutes/Acts/ Act No. 3561, November 26, 1929 .csv
# 2024-11-14 16:40:15,578 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1929/act_3560_1929.html
# 2024-11-14 16:40:15,871 - INFO - Data saved to Data/Statutes/Acts/ Act No. 3560, November 26, 1929 .csv
# 2024-11-14 16:40:15,872 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1929/act_3559_1929.html
# 2024-11-14 16:40:16,174 - INFO - Data saved to Data/Statutes/Acts/ Act No. 3559, November 26, 1929 .csv
# 2024-11-14 16:40:16,175 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1929/act_3558_1929.html
# 2024-11-14 16:40:16,787 - INFO - Data saved to Data/Statutes/Acts/ Act No. 3558, November 26, 1929 .csv
# 2024-11-14 16:40:16,799 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1929/act_3557_1929.html
# 2024-11-14 16:40:17,378 - INFO - Data saved to Data/Statutes/Acts/ Act No. 3557, November 25, 1929 .csv
# 2024-11-14 16:40:17,379 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1929/act_3556_1929.html
# 2024-11-14 16:40:17,639 - INFO - Data saved to Data/Statutes/Acts/ Act No. 3556, November 25, 1929 .csv
# 2024-11-14 16:40:17,639 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1929/act_3555_1929.html
# 2024-11-14 16:40:17,906 - INFO - Data saved to Data/Statutes/Acts/ Act No. 3555, November 23, 1929 .csv
# 2024-11-14 16:40:17,906 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1929/act_3554_1929.html
# 2024-11-14 16:40:18,147 - INFO - Data saved to Data/Statutes/Acts/ Act No. 3554, November 23, 1929 .csv
# 2024-11-14 16:40:18,148 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1929/act_3553_1929.html
# 2024-11-14 16:40:18,428 - INFO - Data saved to Data/Statutes/Acts/ Act No. 3553, November 23, 1929 .csv
# 2024-11-14 16:40:18,428 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1929/act_3552_1929.html
# 2024-11-14 16:40:19,070 - INFO - Data saved to Data/Statutes/Acts/ Act No. 3552, November 23, 1929 .csv
# 2024-11-14 16:40:19,071 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1929/act_3551_1929.html
# 2024-11-14 16:40:19,435 - INFO - Data saved to Data/Statutes/Acts/ Act No. 3551, November 23, 1929 .csv
# 2024-11-14 16:40:19,436 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1929/act_3550_1929.html
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 105
#     102             logger.warning(f"Skipping due to incomplete data for URL: {url}")
#     104 if __name__ == "__main__":
# --> 105     main()
#
# Cell In[3], line 98, in main()
#      96 for url, title in act_links:
#      97     logger.info(f"Processing URL: {url}")
# ---> 98     number, title, data = parse_act_page(url)
#      99     if number and title and data:
#     100         save_to_csv(number, title, data)
#
# Cell In[3], line 58, in parse_act_page(url)
#      56 def parse_act_page(url):
#      57     """Parses the act page to retrieve the Number, Title, and Data."""
# ---> 58     html = fetch_page(url)
#      59     if not html:
#      60         return None, None, None
#
# Cell In[3], line 23, in fetch_page(url)
#      21 """Fetches the HTML content of a given URL."""
#      22 try:
# ---> 23     response = requests.get(url)
#      24     response.raise_for_status()
#      25     return response.text
#
# File ~/scrape/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/scrape/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/scrape/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/scrape/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/scrape/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/scrape/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/scrape/lib/python3.12/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
#     464     # Trigger any extra validation we need to do.
#     465     try:
# --> 466         self._validate_conn(conn)
#     467     except (SocketTimeout, BaseSSLError) as e:
#     468         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/scrape/lib/python3.12/site-packages/urllib3/connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1093 # Force connect early to allow us to validate the connection.
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1098 if not conn.is_verified and not conn.proxy_is_verified:
#
# File ~/scrape/lib/python3.12/site-packages/urllib3/connection.py:730, in HTTPSConnection.connect(self)
#     727     # Remove trailing '.' from fqdn hostnames to allow certificate validation
#     728     server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 730     sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     731         sock=sock,
#     732         cert_reqs=self.cert_reqs,
#     733         ssl_version=self.ssl_version,
#     734         ssl_minimum_version=self.ssl_minimum_version,
#     735         ssl_maximum_version=self.ssl_maximum_version,
#     736         ca_certs=self.ca_certs,
#     737         ca_cert_dir=self.ca_cert_dir,
#     738         ca_cert_data=self.ca_cert_data,
#     739         cert_file=self.cert_file,
#     740         key_file=self.key_file,
#     741         key_password=self.key_password,
#     742         server_hostname=server_hostname_rm_dot,
#     743         ssl_context=self.ssl_context,
#     744         tls_in_tls=tls_in_tls,
#     745         assert_hostname=self.assert_hostname,
#     746         assert_fingerprint=self.assert_fingerprint,
#     747     )
#     748     self.sock = sock_and_verified.socket
#     750 # If an error occurs during connection/handshake we may need to release
#     751 # our lock so another connection can probe the origin.
#
# File ~/scrape/lib/python3.12/site-packages/urllib3/connection.py:909, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     906     if is_ipaddress(normalized):
#     907         server_hostname = normalized
# --> 909 ssl_sock = ssl_wrap_socket(
#     910     sock=sock,
#     911     keyfile=key_file,
#     912     certfile=cert_file,
#     913     key_password=key_password,
#     914     ca_certs=ca_certs,
#     915     ca_cert_dir=ca_cert_dir,
#     916     ca_cert_data=ca_cert_data,
#     917     server_hostname=server_hostname,
#     918     ssl_context=context,
#     919     tls_in_tls=tls_in_tls,
#     920 )
#     922 try:
#     923     if assert_fingerprint:
#
# File ~/scrape/lib/python3.12/site-packages/urllib3/util/ssl_.py:469, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     465         context.load_cert_chain(certfile, keyfile, key_password)
#     467 context.set_alpn_protocols(ALPN_PROTOCOLS)
# --> 469 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     470 return ssl_sock
#
# File ~/scrape/lib/python3.12/site-packages/urllib3/util/ssl_.py:513, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     510     SSLTransport._validate_ssl_context_for_tls_in_tls(ssl_context)
#     511     return SSLTransport(sock, ssl_context, server_hostname)
# --> 513 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:455, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     449 def wrap_socket(self, sock, server_side=False,
#     450                 do_handshake_on_connect=True,
#     451                 suppress_ragged_eofs=True,
#     452                 server_hostname=None, session=None):
#     453     # SSLSocket class handles server_hostname encoding before it calls
#     454     # ctx._wrap_socket()
# --> 455     return self.sslsocket_class._create(
#     456         sock=sock,
#     457         server_side=server_side,
#     458         do_handshake_on_connect=do_handshake_on_connect,
#     459         suppress_ragged_eofs=suppress_ragged_eofs,
#     460         server_hostname=server_hostname,
#     461         context=self,
#     462         session=session
#     463     )
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1042, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039             if timeout == 0.0:
#    1040                 # non-blocking
#    1041                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1042             self.do_handshake()
#    1043 except:
#    1044     try:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1320, in SSLSocket.do_handshake(self, block)
#    1318     if timeout == 0.0 and block:
#    1319         self.settimeout(None)
# -> 1320     self._sslobj.do_handshake()
#    1321 finally:
#    1322     self.settimeout(timeout)
#
# KeyboardInterrupt:
