# %%
import os
import requests
import logging
import pandas as pd
import re
import time
from bs4 import BeautifulSoup

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger()

# Base URL for linking
base_url = "https://lawphil.net/statutes/acts/"
start_url = "https://lawphil.net/statutes/acts/acts.html"

# Directory to save the data files
data_dir = "Data/Statutes/Acts"
os.makedirs(data_dir, exist_ok=True)

# Define delay and maximum retries
REQUEST_DELAY = 0  # seconds between requests
MAX_RETRIES = 3
TIMEOUT = 10  # seconds before timing out the request

def fetch_page(url):
    """Fetches the HTML content of a given URL with retries and timeout."""
    retries = 0
    while retries < MAX_RETRIES:
        try:
            response = requests.get(url, timeout=TIMEOUT)
            response.raise_for_status()
            time.sleep(REQUEST_DELAY)  # Delay between requests
            return response.text
        except requests.RequestException as e:
            retries += 1
            logger.error(f"Attempt {retries} - Failed to fetch page: {url}. Error: {e}")
            if retries >= MAX_RETRIES:
                logger.error(f"Max retries reached. Skipping URL: {url}")
                return None
            time.sleep(REQUEST_DELAY * (2 ** retries))  # Exponential backoff

def parse_main_page(html):
    """Parses the main page to find the desired table with the list of acts."""
    soup = BeautifulSoup(html, 'html.parser')
    table = soup.find('table', {'id': 's-menu'})
    links = []
    
    if not table:
        logger.error("No table with id 's-menu' found on the page.")
        return links
    
    # Process rows within the table
    for row in table.find_all('tr')[1:]:  # Skip the header row
        columns = row.find_all('td')
        if len(columns) < 2:
            continue

        number_link = columns[0].find('a')
        title = columns[1].text.strip()
        
        if number_link and number_link['href']:
            full_link = base_url + number_link['href']
            links.append((full_link, title))
    
    logger.info(f"Found {len(links)} links in the table.")
    return links

def parse_act_page(url):
    """Parses the act page to retrieve the Number, Title, and Data."""
    html = fetch_page(url)
    if not html:
        return None, None, None

    soup = BeautifulSoup(html, 'html.parser')
    blockquote = soup.find('blockquote')
    if not blockquote:
        logger.warning(f"No blockquote found on page: {url}")
        return None, None, None

    paragraphs = blockquote.find_all('p')
    if len(paragraphs) < 2:
        logger.warning(f"Insufficient paragraphs in blockquote at: {url}")
        return None, None, None

    # Clean the 'Number' by removing square brackets and extra spaces
    number = paragraphs[0].text.strip()
    number = re.sub(r'[\[\]]', '', number)  # Remove square brackets

    title = paragraphs[1].text.strip()
    data = blockquote.text.strip()
    
    return number, title, data

def save_to_csv(number, title, data):
    """Saves the act information to a CSV file in the data directory."""
    file_path = os.path.join(data_dir, f"{number}.csv")
    df = pd.DataFrame([[number, title, data]], columns=["Number", "Title", "Data"])
    df.to_csv(file_path, index=False, encoding='utf-8')
    logger.info(f"Data saved to {file_path}")

def main():
    logger.info("Script started.")
    main_page_html = fetch_page(start_url)
    if not main_page_html:
        logger.error("Failed to retrieve main page.")
        return

    act_links = parse_main_page(main_page_html)
    for url, title in act_links:
        logger.info(f"Processing URL: {url}")
        number, title, data = parse_act_page(url)
        if number and title and data:
            save_to_csv(number, title, data)
        else:
            logger.warning(f"Skipping due to incomplete data for URL: {url}")
    
    logger.info("Script completed.")

if __name__ == "__main__":
    main()
# Out:
# 2024-11-14 21:19:47,461 - INFO - Script started.
# 2024-11-14 21:19:50,490 - INFO - Found 4334 links in the table.
# 2024-11-14 21:19:50,491 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4275_1935.html
# 2024-11-14 21:19:50,806 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4275, November 14, 1935 .csv
# 2024-11-14 21:19:50,807 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4274_1935.html
# 2024-11-14 21:19:51,103 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4274, November 14, 1935 .csv
# 2024-11-14 21:19:51,104 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4273_1935.html
# 2024-11-14 21:19:51,369 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4273, November 14, 1935 .csv
# 2024-11-14 21:19:51,370 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4272_1935.html
# 2024-11-14 21:19:51,708 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4272, November 14, 1935 .csv
# 2024-11-14 21:19:51,709 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4271_1935.html
# 2024-11-14 21:19:52,057 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4271, November 14, 1935 .csv
# 2024-11-14 21:19:52,058 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4270_1935.html
# 2024-11-14 21:19:52,308 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4270, November 14, 1935 .csv
# 2024-11-14 21:19:52,309 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4269_1935.html
# 2024-11-14 21:19:52,576 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4269, November 08, 1935 .csv
# 2024-11-14 21:19:52,577 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4268_1935.html
# 2024-11-14 21:19:52,833 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4268, November 08, 1935 .csv
# 2024-11-14 21:19:52,834 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4267_1935.html
# 2024-11-14 21:19:53,114 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4267, November 07, 1935 .csv
# 2024-11-14 21:19:53,115 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4266_1935.html
# 2024-11-14 21:19:53,368 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4266, November 07, 1935 .csv
# 2024-11-14 21:19:53,370 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4265_1935.html
# 2024-11-14 21:19:53,642 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4265, November 07, 1935 .csv
# 2024-11-14 21:19:53,644 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4264_1935.html
# 2024-11-14 21:19:53,899 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4264, November 07, 1935 .csv
# 2024-11-14 21:19:53,900 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4263_1935.html
# 2024-11-14 21:19:54,169 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4263, November 07, 1935 .csv
# 2024-11-14 21:19:54,171 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4262_1935.html
# 2024-11-14 21:19:54,451 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4262, November 07, 1935 .csv
# 2024-11-14 21:19:54,452 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4261_1935.html
# 2024-11-14 21:19:54,702 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4261, November 07, 1935 .csv
# 2024-11-14 21:19:54,703 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4260_1935.html
# 2024-11-14 21:19:54,979 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4260, November 06, 1935 .csv
# 2024-11-14 21:19:54,980 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4259_1935.html
# 2024-11-14 21:19:55,244 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4259, November 06, 1935 .csv
# 2024-11-14 21:19:55,245 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4258_1935.html
# 2024-11-14 21:19:55,517 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4258, November 06, 1935 .csv
# 2024-11-14 21:19:55,518 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4257_1935.html
# 2024-11-14 21:19:55,827 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4257, November 06, 1935 .csv
# 2024-11-14 21:19:55,828 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4256_1935.html
# 2024-11-14 21:19:56,067 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4256, November 06, 1935 .csv
# 2024-11-14 21:19:56,068 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4255_1935.html
# 2024-11-14 21:19:56,333 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4255, November 06, 1935 .csv
# 2024-11-14 21:19:56,333 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4254_1935.html
# 2024-11-14 21:19:56,577 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4254, November 06, 1935 .csv
# 2024-11-14 21:19:56,579 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4253_1935.html
# 2024-11-14 21:19:56,844 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4253, November 06, 1935 .csv
# 2024-11-14 21:19:56,845 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4252_1935.html
# 2024-11-14 21:19:57,116 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4252, November 06, 1935 .csv
# 2024-11-14 21:19:57,117 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4251_1935.html
# 2024-11-14 21:19:57,405 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4251, November 06, 1935 .csv
# 2024-11-14 21:19:57,406 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4250_1935.html
# 2024-11-14 21:19:57,642 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4250, November 06, 1935 .csv
# 2024-11-14 21:19:57,643 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4249_1935.html
# 2024-11-14 21:19:57,964 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4249, November 06, 1935 .csv
# 2024-11-14 21:19:57,965 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4248_1935.html
# 2024-11-14 21:19:58,220 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4248, October 31, 1935 .csv
# 2024-11-14 21:19:58,220 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4247_1935.html
# 2024-11-14 21:19:58,464 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4247, October 28, 1935 .csv
# 2024-11-14 21:19:58,465 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4246_1935.html
# 2024-11-14 21:19:58,756 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4246, October 28, 1935 .csv
# 2024-11-14 21:19:58,757 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4245_1935.html
# 2024-11-14 21:19:59,044 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4245, October 14, 1935 .csv
# 2024-11-14 21:19:59,044 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4244_1935.html
# 2024-11-14 21:19:59,301 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4244, October 10, 1935 .csv
# 2024-11-14 21:19:59,302 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4243_1935.html
# 2024-11-14 21:19:59,560 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4243, September 21, 1935 .csv
# 2024-11-14 21:19:59,560 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4242_1935.html
# 2024-11-14 21:19:59,832 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4242, August 26, 1935 .csv
# 2024-11-14 21:19:59,833 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4241_1935.html
# 2024-11-14 21:20:00,079 - INFO - Data saved to Data/Statutes/Acts/ Act No. 4241, August 23, 1935 .csv
# 2024-11-14 21:20:00,080 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4240_1935.html
# 2024-11-14 21:20:00,351 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4240, August 22, 1935 .csv
# 2024-11-14 21:20:00,352 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4239_1935.html
# 2024-11-14 21:20:00,626 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4239, August 22, 1935 .csv
# 2024-11-14 21:20:00,627 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4238_1935.html
# 2024-11-14 21:20:00,880 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4238, August 21, 1935 .csv
# 2024-11-14 21:20:00,880 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4237_1935.html
# 2024-11-14 21:20:01,154 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4237, August 20, 1935 .csv
# 2024-11-14 21:20:01,155 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4236_1935.html
# 2024-11-14 21:20:01,410 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4236, August 20, 1935 .csv
# 2024-11-14 21:20:01,410 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4235_1935.html
# 2024-11-14 21:20:01,678 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4235, August 20, 1935 .csv
# 2024-11-14 21:20:01,679 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4234_1935.html
# 2024-11-14 21:20:01,922 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4234, August 16, 1935 .csv
# 2024-11-14 21:20:01,922 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4233_1935.html
# 2024-11-14 21:20:02,170 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4233, August 16, 1935 .csv
# 2024-11-14 21:20:02,170 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4232_1935.html
# 2024-11-14 21:20:02,432 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4232, August 16, 1935 .csv
# 2024-11-14 21:20:02,434 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4231_1935.html
# 2024-11-14 21:20:02,819 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4231, August 16, 1935 .csv
# 2024-11-14 21:20:02,820 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4230_1935.html
# 2024-11-14 21:20:03,100 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4230, August 16, 1935 .csv
# 2024-11-14 21:20:03,101 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4229_1935.html
# 2024-11-14 21:20:03,348 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4229, August 12, 1935 .csv
# 2024-11-14 21:20:03,349 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4228_1935.html
# 2024-11-14 21:20:03,623 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4228, August 10, 1935 .csv
# 2024-11-14 21:20:03,623 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4227_1935.html
# 2024-11-14 21:20:03,884 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4227, August 09, 1935 .csv
# 2024-11-14 21:20:03,884 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4226_1935.html
# 2024-11-14 21:20:04,141 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4226, August 09, 1935 .csv
# 2024-11-14 21:20:04,142 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4225_1935.html
# 2024-11-14 21:20:04,402 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4225, August 08, 1935 .csv
# 2024-11-14 21:20:04,403 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4224_1935.html
# 2024-11-14 21:20:04,677 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4224, August 07, 1935 .csv
# 2024-11-14 21:20:04,678 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4223_1935.html
# 2024-11-14 21:20:04,914 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4223, August 07, 1935 .csv
# 2024-11-14 21:20:04,915 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4222_1935.html
# 2024-11-14 21:20:05,169 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4222, August 07, 1935 .csv
# 2024-11-14 21:20:05,170 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4221_1935.html
# 2024-11-14 21:20:05,427 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4221, August 07, 1935 .csv
# 2024-11-14 21:20:05,428 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4220_1935.html
# 2024-11-14 21:20:05,694 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4220, August 06, 1935 .csv
# 2024-11-14 21:20:05,695 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4219_1935.html
# 2024-11-14 21:20:05,951 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4219, August 06, 1935 .csv
# 2024-11-14 21:20:05,952 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4218_1935.html
# 2024-11-14 21:20:06,196 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4218, August 06, 1935 .csv
# 2024-11-14 21:20:06,196 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4217_1935.html
# 2024-11-14 21:20:06,554 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4217, August 06, 1935 .csv
# 2024-11-14 21:20:06,556 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4216_1935.html
# 2024-11-14 21:20:06,828 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4216, August 05, 1935 .csv
# 2024-11-14 21:20:06,829 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4215_1935.html
# 2024-11-14 21:20:07,079 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4215, August 05, 1935 .csv
# 2024-11-14 21:20:07,080 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4214_1935.html
# 2024-11-14 21:20:07,330 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4214, August 05, 1935 .csv
# 2024-11-14 21:20:07,331 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4213_1935.html
# 2024-11-14 21:20:07,598 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4213, August 03, 1935 .csv
# 2024-11-14 21:20:07,599 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4212_1935.html
# 2024-11-14 21:20:07,868 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4212, August 02, 1935 .csv
# 2024-11-14 21:20:07,870 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4211_1935.html
# 2024-11-14 21:20:08,115 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4211, August 02, 1935 .csv
# 2024-11-14 21:20:08,115 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4210_1935.html
# 2024-11-14 21:20:08,392 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4210, August 02, 1935 .csv
# 2024-11-14 21:20:08,393 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4209_1935.html
# 2024-11-14 21:20:08,677 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4209, August 01, 1935 .csv
# 2024-11-14 21:20:08,678 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4208_1935.html
# 2024-11-14 21:20:08,945 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4208, August 01, 1935 .csv
# 2024-11-14 21:20:08,946 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4207_1935.html
# 2024-11-14 21:20:09,210 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4207, August 01, 1935 .csv
# 2024-11-14 21:20:09,211 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4206_1935.html
# 2024-11-14 21:20:09,471 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4206, July 30, 1935 .csv
# 2024-11-14 21:20:09,472 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4205_1935.html
# 2024-11-14 21:20:09,738 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4205, July 25, 1935 .csv
# 2024-11-14 21:20:09,739 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4204_1935.html
# 2024-11-14 21:20:10,000 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4204, July 23, 1935 .csv
# 2024-11-14 21:20:10,001 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4203_1935.html
# 2024-11-14 21:20:10,366 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4203, July 23, 1935 .csv
# 2024-11-14 21:20:10,367 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4202_1935.html
# 2024-11-14 21:20:10,646 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4202, June 20, 1935 .csv
# 2024-11-14 21:20:10,648 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4201_1935.html
# 2024-11-14 21:20:10,958 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4201, June 13, 1935 .csv
# 2024-11-14 21:20:10,959 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4200_1935.html
# 2024-11-14 21:20:11,211 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4200, April 08, 1935 .csv
# 2024-11-14 21:20:11,212 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4199_1935.html
# 2024-11-14 21:20:11,524 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4199, March 16, 1935 .csv
# 2024-11-14 21:20:11,525 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4198_1935.html
# 2024-11-14 21:20:11,805 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4198, March 04, 1935 .csv
# 2024-11-14 21:20:11,806 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4197_1935.html
# 2024-11-14 21:20:12,131 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4197, February 12, 1935 .csv
# 2024-11-14 21:20:12,132 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4196_1935.html
# 2024-11-14 21:20:12,387 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4196, February 05, 1935 .csv
# 2024-11-14 21:20:12,388 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4195_1935.html
# 2024-11-14 21:20:12,656 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4195, February 01, 1935 .csv
# 2024-11-14 21:20:12,657 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4194_1934.html
# 2024-11-14 21:20:12,933 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4194, December 08, 1934 .csv
# 2024-11-14 21:20:12,934 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4193_1934.html
# 2024-11-14 21:20:13,209 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4193, December 08, 1934 .csv
# 2024-11-14 21:20:13,209 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4192_1934.html
# 2024-11-14 21:20:13,465 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4192, December 08, 1934 .csv
# 2024-11-14 21:20:13,466 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4191_1934.html
# 2024-11-14 21:20:13,794 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4191, December 08, 1934 .csv
# 2024-11-14 21:20:13,794 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4190_1934.html
# 2024-11-14 21:20:14,064 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4190, December 08, 1934 .csv
# 2024-11-14 21:20:14,065 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4189_1934.html
# 2024-11-14 21:20:14,323 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4189, December 08, 1934 .csv
# 2024-11-14 21:20:14,323 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4188_1934.html
# 2024-11-14 21:20:14,574 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4188, December 08, 1934 .csv
# 2024-11-14 21:20:14,574 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4187_1934.html
# 2024-11-14 21:20:14,909 - INFO - Data saved to Data/Statutes/Acts/ Act No. 4187, December 08, 1934 .csv
# 2024-11-14 21:20:14,910 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4186_1934.html
# 2024-11-14 21:20:15,168 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4186, December 08, 1934 .csv
# 2024-11-14 21:20:15,169 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4185_1934.html
# 2024-11-14 21:20:15,453 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4185, December 07, 1934 .csv
# 2024-11-14 21:20:15,454 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4184_1934.html
# 2024-11-14 21:20:15,727 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4184, December 07, 1934 .csv
# 2024-11-14 21:20:15,728 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4183_1934.html
# 2024-11-14 21:20:15,984 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4183, December 07, 1934 .csv
# 2024-11-14 21:20:15,985 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4182_1934.html
# 2024-11-14 21:20:16,281 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4182, December 07, 1934 .csv
# 2024-11-14 21:20:16,284 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4181_1934.html
# 2024-11-14 21:20:16,562 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4181, December 07, 1934 .csv
# 2024-11-14 21:20:16,563 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4180_1934.html
# 2024-11-14 21:20:16,823 - INFO - Data saved to Data/Statutes/Acts/ Act No. 4180, December 06, 1934 .csv
# 2024-11-14 21:20:16,824 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4179_1934.html
# 2024-11-14 21:20:17,065 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4179, December 06, 1934 .csv
# 2024-11-14 21:20:17,065 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4178_1934.html
# 2024-11-14 21:20:17,317 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4178, December 05, 1934 .csv
# 2024-11-14 21:20:17,318 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4177_1934.html
# 2024-11-14 21:20:17,595 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4177, December 05, 1934 .csv
# 2024-11-14 21:20:17,596 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4176_1934.html
# 2024-11-14 21:20:17,828 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4176, December 05, 1934 .csv
# 2024-11-14 21:20:17,829 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4175_1934.html
# 2024-11-14 21:20:18,062 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4175, December 05, 1934 .csv
# 2024-11-14 21:20:18,063 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4174_1934.html
# 2024-11-14 21:20:18,308 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4174, December 04, 1934 .csv
# 2024-11-14 21:20:18,309 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4173_1934.html
# 2024-11-14 21:20:18,629 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4173, December 04, 1934 .csv
# 2024-11-14 21:20:18,630 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4172_1934.html
# 2024-11-14 21:20:18,903 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4172, December 04, 1934 .csv
# 2024-11-14 21:20:18,904 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4171_1934.html
# 2024-11-14 21:20:19,164 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4171, December 04, 1934 .csv
# 2024-11-14 21:20:19,165 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4170_1934.html
# 2024-11-14 21:20:19,430 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4170, December 03, 1934 .csv
# 2024-11-14 21:20:19,431 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4169_1934.html
# 2024-11-14 21:20:19,686 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4169, December 03, 1934 .csv
# 2024-11-14 21:20:19,687 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4168_1934.html
# 2024-11-14 21:20:20,139 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4168, December 03, 1934 .csv
# 2024-11-14 21:20:20,140 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4167_1934.html
# 2024-11-14 21:20:21,036 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4167, December 03, 1934 .csv
# 2024-11-14 21:20:21,037 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4166_1934.html
# 2024-11-14 21:20:21,918 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4166, December 04, 1934 .csv
# 2024-11-14 21:20:21,920 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4165_1934.html
# 2024-11-14 21:20:22,364 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4165, December 03, 1934 .csv
# 2024-11-14 21:20:22,365 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4164_1934.html
# 2024-11-14 21:20:22,700 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4164, December 01, 1934 .csv
# 2024-11-14 21:20:22,701 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4163_1934.html
# 2024-11-14 21:20:23,085 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4163, December 01, 1934 .csv
# 2024-11-14 21:20:23,087 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4162_1934.html
# 2024-11-14 21:20:23,346 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4162, December 01, 1934 .csv
# 2024-11-14 21:20:23,347 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4161_1934.html
# 2024-11-14 21:20:23,608 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4161, December 01, 1934 .csv
# 2024-11-14 21:20:23,609 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4160_1934.html
# 2024-11-14 21:20:23,863 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4160, December 01, 1934 .csv
# 2024-11-14 21:20:23,864 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4159_1934.html
# 2024-11-14 21:20:24,127 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4159, December 01, 1934 .csv
# 2024-11-14 21:20:24,128 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4158_1934.html
# 2024-11-14 21:20:24,407 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4158, December 01, 1934 .csv
# 2024-11-14 21:20:24,409 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4157_1934.html
# 2024-11-14 21:20:24,679 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4157, December 01, 1934 .csv
# 2024-11-14 21:20:24,681 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4156_1934.html
# 2024-11-14 21:20:24,929 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4156, December 01, 1934 .csv
# 2024-11-14 21:20:24,930 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4155_1934.html
# 2024-11-14 21:20:25,186 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4155, December 01, 1934 .csv
# 2024-11-14 21:20:25,188 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4154_1934.html
# 2024-11-14 21:20:25,476 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4154, December 01, 1934 .csv
# 2024-11-14 21:20:25,477 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4153_1934.html
# 2024-11-14 21:20:25,765 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4153, November 28, 1934 .csv
# 2024-11-14 21:20:25,766 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4152_1934.html
# 2024-11-14 21:20:26,043 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4152, November 28, 1934 .csv
# 2024-11-14 21:20:26,044 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4151_1934.html
# 2024-11-14 21:20:26,319 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4151, November 28, 1934 .csv
# 2024-11-14 21:20:26,320 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4150_1934.html
# 2024-11-14 21:20:26,973 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4150, November 28, 1934 .csv
# 2024-11-14 21:20:26,975 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4149_1934.html
# 2024-11-14 21:20:28,305 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4149, November 28, 1934 .csv
# 2024-11-14 21:20:28,306 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4148_1934.html
# 2024-11-14 21:20:29,120 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4148, November 28, 1934 .csv
# 2024-11-14 21:20:29,121 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4147_1934.html
# 2024-11-14 21:20:29,402 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4147, November 28, 1934 .csv
# 2024-11-14 21:20:29,404 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4146_1934.html
# 2024-11-14 21:20:29,660 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4146, November 26, 1934 .csv
# 2024-11-14 21:20:29,662 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4145_1934.html
# 2024-11-14 21:20:29,922 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4145, November 26, 1934 .csv
# 2024-11-14 21:20:29,923 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4144_1934.html
# 2024-11-14 21:20:30,191 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4144, November 26, 1934 .csv
# 2024-11-14 21:20:30,192 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4143_1934.html
# 2024-11-14 21:20:30,450 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4143, November 26, 1934 .csv
# 2024-11-14 21:20:30,451 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4142_1934.html
# 2024-11-14 21:20:30,734 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4142, November 24, 1934 .csv
# 2024-11-14 21:20:30,735 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4141_1934.html
# 2024-11-14 21:20:30,978 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4141, November 24, 1934 .csv
# 2024-11-14 21:20:30,979 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4140_1934.html
# 2024-11-14 21:20:31,238 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4140, November 24, 1934 .csv
# 2024-11-14 21:20:31,240 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4139_1934.html
# 2024-11-14 21:20:31,509 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4139, November 23, 1934 .csv
# 2024-11-14 21:20:31,510 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4138_1934.html
# 2024-11-14 21:20:31,765 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4138, November 23, 1934 .csv
# 2024-11-14 21:20:31,766 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4137_1934.html
# 2024-11-14 21:20:32,049 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4137, November 22, 1934 .csv
# 2024-11-14 21:20:32,050 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4136_1934.html
# 2024-11-14 21:20:32,316 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4136, November 22, 1934 .csv
# 2024-11-14 21:20:32,317 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4135_1934.html
# 2024-11-14 21:20:32,576 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4135, November 22, 1934 .csv
# 2024-11-14 21:20:32,578 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4134_1934.html
# 2024-11-14 21:20:33,085 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4134, November 22, 1934 .csv
# 2024-11-14 21:20:33,087 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4133_1934.html
# 2024-11-14 21:20:33,774 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4133, November 22, 1934 .csv
# 2024-11-14 21:20:33,775 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4132_1934.html
# 2024-11-14 21:20:34,391 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4132, November 22, 1934 .csv
# 2024-11-14 21:20:34,393 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4131_1934.html
# 2024-11-14 21:20:35,035 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4131, November 22, 1934 .csv
# 2024-11-14 21:20:35,036 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4130_1934.html
# 2024-11-14 21:20:35,328 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4130, October 30, 1934 .csv
# 2024-11-14 21:20:35,329 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4129_1934.html
# 2024-11-14 21:20:35,578 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4129, October 09, 1934 .csv
# 2024-11-14 21:20:35,579 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4128_1934.html
# 2024-11-14 21:20:35,836 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4128, October 05, 1934 .csv
# 2024-11-14 21:20:35,837 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4127_1934.html
# 2024-11-14 21:20:36,104 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4127, August 21, 1934 .csv
# 2024-11-14 21:20:36,105 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4126_1934.html
# 2024-11-14 21:20:36,399 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4126, May 26, 1934 .csv
# 2024-11-14 21:20:36,401 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4125_1934.html
# 2024-11-14 21:20:36,669 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4125, May 26, 1934 .csv
# 2024-11-14 21:20:36,670 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1934/act_4124_1934.html
# 2024-11-14 21:20:36,960 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4124, February 09, 1934 .csv
# 2024-11-14 21:20:36,961 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4123_1933.html
# 2024-11-14 21:20:37,234 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4123, December 09, 1933 .csv
# 2024-11-14 21:20:37,235 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4122_1933.html
# 2024-11-14 21:20:37,927 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4122, December 09, 1933 .csv
# 2024-11-14 21:20:37,928 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4121_1933.html
# 2024-11-14 21:20:38,667 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4121, December 08, 1933 .csv
# 2024-11-14 21:20:38,669 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4120_1933.html
# 2024-11-14 21:20:39,286 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4120, December 08, 1933 .csv
# 2024-11-14 21:20:39,287 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4119_1933.html
# 2024-11-14 21:20:39,558 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4119, December 08, 1933 .csv
# 2024-11-14 21:20:39,560 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4118_1933.html
# 2024-11-14 21:20:39,813 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4118, December 07, 1933 .csv
# 2024-11-14 21:20:39,814 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4117_1933.html
# 2024-11-14 21:20:40,113 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4117, December 07, 1933 .csv
# 2024-11-14 21:20:40,114 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4116_1933.html
# 2024-11-14 21:20:40,380 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4116, December 07, 1933 .csv
# 2024-11-14 21:20:40,381 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4115_1933.html
# 2024-11-14 21:20:40,655 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4115, December 07, 1933 .csv
# 2024-11-14 21:20:40,657 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4114_1933.html
# 2024-11-14 21:20:40,925 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4114, December 07, 1933 .csv
# 2024-11-14 21:20:40,926 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4113_1933.html
# 2024-11-14 21:20:41,218 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4113, December 07, 1933 .csv
# 2024-11-14 21:20:41,220 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4112_1933.html
# 2024-11-14 21:20:41,483 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4112, December 07, 1933 .csv
# 2024-11-14 21:20:41,484 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4111_1933.html
# 2024-11-14 21:20:41,732 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4111, December 06, 1933 .csv
# 2024-11-14 21:20:41,734 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4110_1933.html
# 2024-11-14 21:20:41,989 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4110, December 06, 1933 .csv
# 2024-11-14 21:20:41,990 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4109_1933.html
# 2024-11-14 21:20:42,297 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4109, December 06, 1933 .csv
# 2024-11-14 21:20:42,299 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4108_1933.html
# 2024-11-14 21:20:42,573 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4108, December 06, 1933 .csv
# 2024-11-14 21:20:42,575 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4107_1933.html
# 2024-11-14 21:20:42,870 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4107, December 06, 1933 .csv
# 2024-11-14 21:20:42,872 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4106_1933.html
# 2024-11-14 21:20:43,122 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4106, December 05, 1933 .csv
# 2024-11-14 21:20:43,123 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4105_1933.html
# 2024-11-14 21:20:43,381 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4105, December 05, 1933 .csv
# 2024-11-14 21:20:43,383 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4104_1933.html
# 2024-11-14 21:20:43,661 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4104, December 05, 1933 .csv
# 2024-11-14 21:20:43,662 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4103_1933.html
# 2024-11-14 21:20:43,913 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4103, December 05, 1933 .csv
# 2024-11-14 21:20:43,914 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4102_1933.html
# 2024-11-14 21:20:44,172 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4102, December 05, 1933 .csv
# 2024-11-14 21:20:44,173 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4101_1933.html
# 2024-11-14 21:20:44,417 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4101, December 01, 1933 .csv
# 2024-11-14 21:20:44,418 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4100_1933.html
# 2024-11-14 21:20:44,695 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4100, November 29, 1933 .csv
# 2024-11-14 21:20:44,697 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4099_1933.html
# 2024-11-14 21:20:44,960 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4099, November 29, 1933 .csv
# 2024-11-14 21:20:44,961 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4098_1933.html
# 2024-11-14 21:20:45,204 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4098, November 29, 1933 .csv
# 2024-11-14 21:20:45,205 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4097_1933.html
# 2024-11-14 21:20:45,458 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4097, November 29, 1933 .csv
# 2024-11-14 21:20:45,459 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4096_1933.html
# 2024-11-14 21:20:45,746 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4096, November 29, 1933 .csv
# 2024-11-14 21:20:45,747 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4095_1933.html
# 2024-11-14 21:20:46,036 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4095, November 29, 1933 .csv
# 2024-11-14 21:20:46,036 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4094_1933.html
# 2024-11-14 21:20:46,305 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4094, November 29, 1933 .csv
# 2024-11-14 21:20:46,305 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4093_1933.html
# 2024-11-14 21:20:46,555 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4093, November 29, 1933 .csv
# 2024-11-14 21:20:46,556 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4092_1933.html
# 2024-11-14 21:20:46,823 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4092, November 29, 1933 .csv
# 2024-11-14 21:20:46,824 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4091_1933.html
# 2024-11-14 21:20:47,079 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4091, November 29, 1933 .csv
# 2024-11-14 21:20:47,080 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4090_1933.html
# 2024-11-14 21:20:47,378 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4090, November 29, 1933 .csv
# 2024-11-14 21:20:47,379 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4089_1933.html
# 2024-11-14 21:20:47,646 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4089, November 29, 1933 .csv
# 2024-11-14 21:20:47,646 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4088_1933.html
# 2024-11-14 21:20:47,901 - INFO - Data saved to Data/Statutes/Acts/ Act No. 4088, November 29, 1933 .csv
# 2024-11-14 21:20:47,901 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4087_1933.html
# 2024-11-14 21:20:48,152 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4087, November 29, 1933 .csv
# 2024-11-14 21:20:48,153 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4086_1933.html
# 2024-11-14 21:20:48,418 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4086, November 29, 1933 .csv
# 2024-11-14 21:20:48,419 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4085_1933.html
# 2024-11-14 21:20:48,686 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4085, November 29, 1933 .csv
# 2024-11-14 21:20:48,687 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4084_1933.html
# 2024-11-14 21:20:48,966 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4084, November 29, 1933 .csv
# 2024-11-14 21:20:48,968 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4083_1933.html
# 2024-11-14 21:20:49,231 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4083, November 29, 1933 .csv
# 2024-11-14 21:20:49,233 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4082_1933.html
# 2024-11-14 21:20:49,483 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4082, November 29, 1933 .csv
# 2024-11-14 21:20:49,485 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4081_1933.html
# 2024-11-14 21:20:49,766 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4081, November 29, 1933 .csv
# 2024-11-14 21:20:49,767 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4080_1933.html
# 2024-11-14 21:20:50,052 - INFO - Data saved to Data/Statutes/Acts/ Act No. 4080, November 29, 1933 .csv
# 2024-11-14 21:20:50,053 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4079_1933.html
# 2024-11-14 21:20:50,402 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4079, November 29, 1933 .csv
# 2024-11-14 21:20:50,403 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4078_1933.html
# 2024-11-14 21:20:50,679 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4078, November 08, 1933 .csv
# 2024-11-14 21:20:50,680 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4077_1933.html
# 2024-11-14 21:20:51,012 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4077, October 27, 1933 .csv
# 2024-11-14 21:20:51,013 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4076_1933.html
# 2024-11-14 21:20:51,265 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4076, October 27, 1933 .csv
# 2024-11-14 21:20:51,267 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4075_1933.html
# 2024-11-14 21:20:51,528 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4075, October 27, 1933 .csv
# 2024-11-14 21:20:51,529 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4074_1933.html
# 2024-11-14 21:20:51,874 - INFO - Data saved to Data/Statutes/Acts/ Act No. 4074, October 19, 1933 .csv
# 2024-11-14 21:20:51,875 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4073_1933.html
# 2024-11-14 21:20:52,138 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4073, October 12, 1933 .csv
# 2024-11-14 21:20:52,139 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4072_1933.html
# 2024-11-14 21:20:52,402 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4072, October 12, 1933 .csv
# 2024-11-14 21:20:52,403 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4071_1933.html
# 2024-11-14 21:20:52,687 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4071, October 12, 1933 .csv
# 2024-11-14 21:20:52,689 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4070_1933.html
# 2024-11-14 21:20:52,969 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4070, October 12, 1933 .csv
# 2024-11-14 21:20:52,971 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4069_1933.html
# 2024-11-14 21:20:53,221 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4069, October 10, 1933 .csv
# 2024-11-14 21:20:53,223 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4068_1933.html
# 2024-11-14 21:20:53,515 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4068, September 11, 1933 .csv
# 2024-11-14 21:20:53,517 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4067_1933.html
# 2024-11-14 21:20:53,772 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4067, September 04, 1933 .csv
# 2024-11-14 21:20:53,774 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4066_1933.html
# 2024-11-14 21:20:54,031 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4066, August 17, 1933 .csv
# 2024-11-14 21:20:54,032 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4065_1933.html
# 2024-11-14 21:20:54,312 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4065, August 07, 1933 .csv
# 2024-11-14 21:20:54,314 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4064_1933.html
# 2024-11-14 21:20:54,579 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4064, April 29, 1933 .csv
# 2024-11-14 21:20:54,580 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4063_1933.html
# 2024-11-14 21:20:54,864 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4063, March 01, 1933 .csv
# 2024-11-14 21:20:54,865 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4062_1933.html
# 2024-11-14 21:20:55,129 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4062, March 01, 1933 .csv
# 2024-11-14 21:20:55,131 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4061_1933.html
# 2024-11-14 21:20:55,381 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4061, March 01, 1933 .csv
# 2024-11-14 21:20:55,383 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4060_1933.html
# 2024-11-14 21:20:55,729 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4060, March 01, 1933 .csv
# 2024-11-14 21:20:55,730 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4059_1933.html
# 2024-11-14 21:20:56,002 - INFO - Data saved to Data/Statutes/Acts/ Act No. 4059, March 01, 1933 .csv
# 2024-11-14 21:20:56,003 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4058_1933.html
# 2024-11-14 21:20:56,287 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4058, March 01, 1933 .csv
# 2024-11-14 21:20:56,289 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4057_1933.html
# 2024-11-14 21:20:56,550 - INFO - Data saved to Data/Statutes/Acts/ Act No. 4057, March 01, 1933 .csv
# 2024-11-14 21:20:56,551 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4056_1933.html
# 2024-11-14 21:20:56,814 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4056, March 01, 1933 .csv
# 2024-11-14 21:20:56,814 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4055_1933.html
# 2024-11-14 21:20:57,175 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4055, February 27, 1933 .csv
# 2024-11-14 21:20:57,176 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4054_1933.html
# 2024-11-14 21:20:57,510 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4054, February 27, 1933 .csv
# 2024-11-14 21:20:57,511 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4053_1933.html
# 2024-11-14 21:20:57,942 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4053, February 24, 1933 .csv
# 2024-11-14 21:20:57,943 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4052_1933.html
# ...
# 2024-11-14 21:20:59,312 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4048, February 18, 1933 .csv
# 2024-11-14 21:20:59,313 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4047_1933.html
# 2024-11-14 21:20:59,611 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4047, February 18, 1933 .csv
# 2024-11-14 21:20:59,612 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4046_1933.html
# 2024-11-14 21:20:59,889 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4046, February 18, 1933 .csv
# 2024-11-14 21:20:59,890 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4045_1933.html
# 2024-11-14 21:21:00,158 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4045, February 18, 1933 .csv
# 2024-11-14 21:21:00,159 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4044_1933.html
# 2024-11-14 21:21:00,408 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4044, February 18, 1933 .csv
# 2024-11-14 21:21:00,410 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4043_1933.html
# 2024-11-14 21:21:00,688 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4043, February 10, 1933 .csv
# 2024-11-14 21:21:00,689 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4042_1933.html
# 2024-11-14 21:21:00,949 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4042, February 10, 1933 .csv
# 2024-11-14 21:21:00,951 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4041_1933.html
# 2024-11-14 21:21:01,212 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4041, January 21, 1933 .csv
# 2024-11-14 21:21:01,213 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4040_1933.html
# 2024-11-14 21:21:01,501 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4040, January 06, 1933 .csv
# 2024-11-14 21:21:01,503 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1933/act_4039_1933.html
# 2024-11-14 21:21:01,783 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4039, January 06, 1933 .csv
# 2024-11-14 21:21:01,785 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1932/act_4038_1932.html
# 2024-11-14 21:21:02,033 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4038, December 19, 1932 .csv
# 2024-11-14 21:21:02,034 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1932/act_4037_1932.html
# 2024-11-14 21:21:02,283 - INFO - Data saved to Data/Statutes/Acts/ Act No. 4037, December 17, 1932 .csv
# 2024-11-14 21:21:02,284 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1932/act_4036_1932.html
# 2024-11-14 21:21:02,551 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4036, December 17, 1932 .csv
# 2024-11-14 21:21:02,552 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1932/act_4035_1932.html
# 2024-11-14 21:21:02,838 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4035, December 17, 1932 .csv
# 2024-11-14 21:21:02,839 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1932/act_4034_1932.html
# 2024-11-14 21:21:03,187 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4034, December 17, 1932 .csv
# 2024-11-14 21:21:03,188 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1932/act_4033_1932.html
# 2024-11-14 21:21:03,431 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4033, December 09, 1932 .csv
# 2024-11-14 21:21:03,432 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1932/act_4032_1932.html
# 2024-11-14 21:21:03,744 - INFO - Data saved to Data/Statutes/Acts/ Act No. 4032, December 09, 1932 .csv
# 2024-11-14 21:21:03,745 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1932/act_4031_1932.html
# 2024-11-14 21:21:03,997 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4031, December 08, 1932 .csv
# 2024-11-14 21:21:03,998 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1932/act_4030_1932.html
# 2024-11-14 21:21:04,263 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4030, December 08, 1932 .csv
# 2024-11-14 21:21:04,264 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1932/act_4029_1932.html
# 2024-11-14 21:21:04,536 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4029, December 08, 1932 .csv
# 2024-11-14 21:21:04,537 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1932/act_4028_1932.html
# 2024-11-14 21:21:04,805 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4028, December 08, 1932 .csv
# 2024-11-14 21:21:04,806 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1932/act_4027_1932.html
# 2024-11-14 21:21:05,061 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4027, December 08, 1932 .csv
# 2024-11-14 21:21:05,062 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1932/act_4026_1932.html
# 2024-11-14 21:21:05,357 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4026, December 08, 1932 .csv
# 2024-11-14 21:21:05,358 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1932/act_4025_1932.html
# 2024-11-14 21:21:05,612 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4025, December 08, 1932 .csv
# 2024-11-14 21:21:05,614 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1932/act_4024_1932.html
# 2024-11-14 21:21:05,861 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4024, December 08, 1932 .csv
# 2024-11-14 21:21:05,862 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1932/act_4023_1932.html
# 2024-11-14 21:21:06,108 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4023, December 08, 1932 .csv
# 2024-11-14 21:21:06,109 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1932/act_4022_1932.html
# 2024-11-14 21:21:06,373 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4022, December 08, 1932 .csv
# 2024-11-14 21:21:06,374 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1932/act_4021_1932.html
# 2024-11-14 21:21:06,646 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4021, December 08, 1932 .csv
# 2024-11-14 21:21:06,648 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1932/act_4020_1932.html
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 121
#     118     logger.info("Script completed.")
#     120 if __name__ == "__main__":
# --> 121     main()
#
# Cell In[3], line 112, in main()
#     110 for url, title in act_links:
#     111     logger.info(f"Processing URL: {url}")
# --> 112     number, title, data = parse_act_page(url)
#     113     if number and title and data:
#     114         save_to_csv(number, title, data)
#
# Cell In[3], line 71, in parse_act_page(url)
#      69 def parse_act_page(url):
#      70     """Parses the act page to retrieve the Number, Title, and Data."""
# ---> 71     html = fetch_page(url)
#      72     if not html:
#      73         return None, None, None
#
# Cell In[3], line 31, in fetch_page(url)
#      29 while retries < MAX_RETRIES:
#      30     try:
# ---> 31         response = requests.get(url, timeout=TIMEOUT)
#      32         response.raise_for_status()
#      33         time.sleep(REQUEST_DELAY)  # Delay between requests
#
# File ~/scrape/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/scrape/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/scrape/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/scrape/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/scrape/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/scrape/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/scrape/lib/python3.12/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
#     464     # Trigger any extra validation we need to do.
#     465     try:
# --> 466         self._validate_conn(conn)
#     467     except (SocketTimeout, BaseSSLError) as e:
#     468         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/scrape/lib/python3.12/site-packages/urllib3/connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1093 # Force connect early to allow us to validate the connection.
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1098 if not conn.is_verified and not conn.proxy_is_verified:
#
# File ~/scrape/lib/python3.12/site-packages/urllib3/connection.py:730, in HTTPSConnection.connect(self)
#     727     # Remove trailing '.' from fqdn hostnames to allow certificate validation
#     728     server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 730     sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     731         sock=sock,
#     732         cert_reqs=self.cert_reqs,
#     733         ssl_version=self.ssl_version,
#     734         ssl_minimum_version=self.ssl_minimum_version,
#     735         ssl_maximum_version=self.ssl_maximum_version,
#     736         ca_certs=self.ca_certs,
#     737         ca_cert_dir=self.ca_cert_dir,
#     738         ca_cert_data=self.ca_cert_data,
#     739         cert_file=self.cert_file,
#     740         key_file=self.key_file,
#     741         key_password=self.key_password,
#     742         server_hostname=server_hostname_rm_dot,
#     743         ssl_context=self.ssl_context,
#     744         tls_in_tls=tls_in_tls,
#     745         assert_hostname=self.assert_hostname,
#     746         assert_fingerprint=self.assert_fingerprint,
#     747     )
#     748     self.sock = sock_and_verified.socket
#     750 # If an error occurs during connection/handshake we may need to release
#     751 # our lock so another connection can probe the origin.
#
# File ~/scrape/lib/python3.12/site-packages/urllib3/connection.py:909, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     906     if is_ipaddress(normalized):
#     907         server_hostname = normalized
# --> 909 ssl_sock = ssl_wrap_socket(
#     910     sock=sock,
#     911     keyfile=key_file,
#     912     certfile=cert_file,
#     913     key_password=key_password,
#     914     ca_certs=ca_certs,
#     915     ca_cert_dir=ca_cert_dir,
#     916     ca_cert_data=ca_cert_data,
#     917     server_hostname=server_hostname,
#     918     ssl_context=context,
#     919     tls_in_tls=tls_in_tls,
#     920 )
#     922 try:
#     923     if assert_fingerprint:
#
# File ~/scrape/lib/python3.12/site-packages/urllib3/util/ssl_.py:469, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     465         context.load_cert_chain(certfile, keyfile, key_password)
#     467 context.set_alpn_protocols(ALPN_PROTOCOLS)
# --> 469 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     470 return ssl_sock
#
# File ~/scrape/lib/python3.12/site-packages/urllib3/util/ssl_.py:513, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     510     SSLTransport._validate_ssl_context_for_tls_in_tls(ssl_context)
#     511     return SSLTransport(sock, ssl_context, server_hostname)
# --> 513 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:455, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     449 def wrap_socket(self, sock, server_side=False,
#     450                 do_handshake_on_connect=True,
#     451                 suppress_ragged_eofs=True,
#     452                 server_hostname=None, session=None):
#     453     # SSLSocket class handles server_hostname encoding before it calls
#     454     # ctx._wrap_socket()
# --> 455     return self.sslsocket_class._create(
#     456         sock=sock,
#     457         server_side=server_side,
#     458         do_handshake_on_connect=do_handshake_on_connect,
#     459         suppress_ragged_eofs=suppress_ragged_eofs,
#     460         server_hostname=server_hostname,
#     461         context=self,
#     462         session=session
#     463     )
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1042, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039             if timeout == 0.0:
#    1040                 # non-blocking
#    1041                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1042             self.do_handshake()
#    1043 except:
#    1044     try:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1320, in SSLSocket.do_handshake(self, block)
#    1318     if timeout == 0.0 and block:
#    1319         self.settimeout(None)
# -> 1320     self._sslobj.do_handshake()
#    1321 finally:
#    1322     self.settimeout(timeout)
#
# KeyboardInterrupt:
