# %%
import os
import csv
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import time
import re
import logging

# Define base URL and main folder for saving data
BASE_URL = "https://lawphil.net/judjuris/judjuris.html"
MAIN_FOLDER = "Data/Jurisprudence"

# Define delay and maximum retries
REQUEST_DELAY = 0  # seconds between requests
TIMEOUT = 10  # seconds before timing out the request

# Configure logging
logging.basicConfig(level=logging.INFO, format='[%(asctime)s] %(levelname)s: %(message)s')
logger = logging.getLogger(__name__)

# Function to create folders if they do not exist
def create_folder(path):
    if not os.path.exists(path):
        os.makedirs(path)

# Function to sanitize filenames and folder names
def sanitize_filename(name, max_length=100):
    # Replace invalid characters and truncate the name if it's too long
    sanitized_name = re.sub(r'[\\/*?:"<>|]', "_", name)
    return sanitized_name[:max_length]  # Ensure the filename doesn't exceed max_length


# Function to check if a folder already contains data
def is_data_collected(year_folder, month_folder):
    # Check if the folder contains any CSV files (indicating data has been collected)
    if not os.path.exists(month_folder):
        create_folder(month_folder)
    return any(file.endswith(".csv") for file in os.listdir(month_folder))

# Function to scrape data from each case page
def scrape_case_data(case_url, year, month, case_number):
    retries = 3
    while retries > 0:
        try:
            response = requests.get(case_url, timeout=TIMEOUT)
            response.raise_for_status()
            case_soup = BeautifulSoup(response.content, 'html.parser')
            blockquote = case_soup.find("blockquote")

            if blockquote:
                paragraphs = blockquote.find_all("p")
                if len(paragraphs) >= 3:
                    # Extract Case Number (remove square brackets), Title, and full data
                    case_number_text = re.sub(r'\[|\]', '', paragraphs[2].get_text(strip=True))
                    title_text = paragraphs[3].get_text(strip=True)
                    case_data = blockquote.get_text(separator="\n").strip()
                    return case_number_text, title_text, case_data
            return None, None, None
        except requests.RequestException as e:
            retries -= 1
            logger.warning(f"Error fetching case data from {case_url}: {e}. Retrying {retries} more times...")
            time.sleep(REQUEST_DELAY * (2 ** retries))  # Exponential backoff
            
    logger.error(f"Failed to fetch case data after retries: {case_url}")
    return None, None, None

# Function to get all links from a page and retry if request fails
def get_links(url, retry=3):
    while retry > 0:
        try:
            response = requests.get(url, timeout=10)
            response.raise_for_status()
            soup = BeautifulSoup(response.content, 'html.parser')
            return soup
        except requests.RequestException as e:
            logger.warning(f"Error fetching {url}: {e}. Retrying {retry - 1} more times...")
            retry -= 1
            time.sleep(2)  # wait before retry
    logger.error(f"Failed to fetch {url} after retries.")
    return None

# Main function to scrape years, months, and cases
def scrape_jurisprudence():
    # Fetch the base index page
    soup = get_links(BASE_URL)
    if not soup:
        logger.error("Failed to fetch the base page.")
        return
    
    # Create the main directory for storing data
    create_folder(MAIN_FOLDER)
    
    # Find all year links and sort them chronologically
    # Find all year links and filter them to start from 1997
    year_links = sorted([link for link in soup.select("a.off_n1") if int(link.get_text()) >= 1997],key=lambda link: int(link.get_text()))

    
    for year_link in year_links:
        year_text = year_link.get_text()
        year_url = urljoin(BASE_URL, year_link['href'])
        year_folder = os.path.join(MAIN_FOLDER, sanitize_filename(year_text))
        create_folder(year_folder)
        
        logger.info(f"Starting processing for year: {year_text}")
        
        # Fetch the year page
        year_soup = get_links(year_url)
        if not year_soup:
            continue
        
        # Find all month links and sort them from January to December
        month_links = sorted(year_soup.select("a.off"), key=lambda link: link.get_text())
        
        for month_link in month_links:
            month_text = month_link.get_text()
            month_folder = os.path.join(year_folder, sanitize_filename(month_text))
            
            # Check if the data for the year and month has already been collected
            if is_data_collected(year_folder, month_folder):
                logger.info(f"Data for {month_text} {year_text} already collected. Skipping.")
                continue

            logger.info(f"Starting processing for month: {month_text} of year {year_text}")
            
            # Fetch the month page
            month_url = urljoin(year_url, month_link['href'])
            month_soup = get_links(month_url)
            if not month_soup:
                continue
            
            # Find all case links on the month page
            case_links = month_soup.find_all("a")
            
            for case_link in case_links:
                # Skip links that don't have an 'href' attribute or are empty
                if 'href' not in case_link.attrs or not case_link['href']:
                    logger.warning(f"Skipping invalid link in month {month_text}, year {year_text}: {case_link}")
                    continue

                case_text = case_link.get_text()
                case_url = urljoin(month_url, case_link['href'])
                
                # Sanitize the case number text to create a valid file name
                case_file_name = sanitize_filename(case_text) + ".csv"
                csv_file_path = os.path.join(month_folder, case_file_name)
                
                logger.info(f"Processing case number: {case_text} in month {month_text}, year {year_text}")
                
                # Scrape case data
                case_number, title, case_data = scrape_case_data(case_url, year_text, month_text, case_text)
                
                if case_data:
                    # Save case data to a CSV file
                    with open(csv_file_path, mode="w", newline='', encoding="utf-8", errors="replace") as csv_file:
                        writer = csv.writer(csv_file)
                        writer.writerow(["Year", "Month", "Case Number", "Title", "Data"])
                        writer.writerow([year_text, month_text, case_number, title, case_data])
                    
                    logger.info(f"Saved case data for {case_text} in month {month_text}, year {year_text}")
                else:
                    logger.warning(f"Skipping case number: {case_text} as no data was found")

                # Respectful delay to avoid hitting the server too hard
                time.sleep(1)

    logger.info("Completed scraping process.")

# Run the scraping process
scrape_jurisprudence()
# Out:
# [2024-11-15 21:01:46,612] INFO: Starting processing for year: 1997
# [2024-11-15 21:01:46,927] INFO: Starting processing for month: April of year 1997
# [2024-11-15 21:01:47,266] WARNING: Skipping invalid link in month April, year 1997: <a name="top"></a>
# [2024-11-15 21:01:47,267] INFO: Processing case number: G.R. No. 110286 in month April, year 1997
# [2024-11-15 21:01:47,625] INFO: Saved case data for G.R. No. 110286 in month April, year 1997
# [2024-11-15 21:01:48,630] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:01:48,632] INFO: Processing case number: G.R. No. 116732 in month April, year 1997
# [2024-11-15 21:01:48,977] INFO: Saved case data for G.R. No. 116732 in month April, year 1997
# [2024-11-15 21:01:49,983] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:01:49,985] INFO: Processing case number: A.M. No. MTJ-97-1114 in month April, year 1997
# [2024-11-15 21:01:50,263] INFO: Saved case data for A.M. No. MTJ-97-1114 in month April, year 1997
# [2024-11-15 21:01:51,268] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:01:51,270] INFO: Processing case number: G.R. No. 100197 in month April, year 1997
# [2024-11-15 21:01:51,705] INFO: Saved case data for G.R. No. 100197 in month April, year 1997
# [2024-11-15 21:01:52,711] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:01:52,713] INFO: Processing case number: G.R. No. 100197 in month April, year 1997
# [2024-11-15 21:01:53,077] INFO: Saved case data for G.R. No. 100197 in month April, year 1997
# [2024-11-15 21:01:54,083] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:01:54,084] INFO: Processing case number: G.R. No. 105556 in month April, year 1997
# [2024-11-15 21:01:54,478] INFO: Saved case data for G.R. No. 105556 in month April, year 1997
# [2024-11-15 21:01:55,484] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:01:55,486] INFO: Processing case number: G.R. No. 112369 in month April, year 1997
# [2024-11-15 21:01:56,496] INFO: Saved case data for G.R. No. 112369 in month April, year 1997
# [2024-11-15 21:01:57,502] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:01:57,503] INFO: Processing case number: G.R. No. 120549 in month April, year 1997
# [2024-11-15 21:01:57,844] INFO: Saved case data for G.R. No. 120549 in month April, year 1997
# [2024-11-15 21:01:58,851] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:01:58,853] INFO: Processing case number: G.R. No. 121667 in month April, year 1997
# [2024-11-15 21:01:59,210] INFO: Saved case data for G.R. No. 121667 in month April, year 1997
# [2024-11-15 21:02:00,216] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:00,219] INFO: Processing case number: G.R. No. 94545 in month April, year 1997
# [2024-11-15 21:02:00,661] INFO: Saved case data for G.R. No. 94545 in month April, year 1997
# [2024-11-15 21:02:01,667] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:01,669] INFO: Processing case number: G.R. Nos. 113692-93 in month April, year 1997
# [2024-11-15 21:02:02,360] INFO: Saved case data for G.R. Nos. 113692-93 in month April, year 1997
# [2024-11-15 21:02:03,365] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:03,370] INFO: Processing case number: G.R. No. 102784 in month April, year 1997
# [2024-11-15 21:02:03,737] INFO: Saved case data for G.R. No. 102784 in month April, year 1997
# [2024-11-15 21:02:04,742] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:04,743] INFO: Processing case number: G.R. No. 74336 in month April, year 1997
# [2024-11-15 21:02:05,675] INFO: Saved case data for G.R. No. 74336 in month April, year 1997
# [2024-11-15 21:02:06,677] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:06,679] INFO: Processing case number: A.M. No. P-94-1070 in month April, year 1997
# [2024-11-15 21:02:07,121] INFO: Saved case data for A.M. No. P-94-1070 in month April, year 1997
# [2024-11-15 21:02:08,127] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:08,128] INFO: Processing case number: G.R. No. 110223 in month April, year 1997
# [2024-11-15 21:02:08,473] INFO: Saved case data for G.R. No. 110223 in month April, year 1997
# [2024-11-15 21:02:09,476] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:09,477] INFO: Processing case number: G.R. No. 118457 in month April, year 1997
# [2024-11-15 21:02:09,818] INFO: Saved case data for G.R. No. 118457 in month April, year 1997
# [2024-11-15 21:02:10,824] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:10,825] INFO: Processing case number: G.R. No. 122801 in month April, year 1997
# [2024-11-15 21:02:11,160] INFO: Saved case data for G.R. No. 122801 in month April, year 1997
# [2024-11-15 21:02:12,166] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:12,167] INFO: Processing case number: G.R. No. 127116 in month April, year 1997
# [2024-11-15 21:02:12,569] INFO: Saved case data for G.R. No. 127116 in month April, year 1997
# [2024-11-15 21:02:13,574] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:13,576] INFO: Processing case number: G.R. Nos. 118813-14 in month April, year 1997
# [2024-11-15 21:02:13,933] INFO: Saved case data for G.R. Nos. 118813-14 in month April, year 1997
# [2024-11-15 21:02:14,934] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:14,936] INFO: Processing case number: A.C. No. 3907 in month April, year 1997
# [2024-11-15 21:02:15,193] INFO: Saved case data for A.C. No. 3907 in month April, year 1997
# [2024-11-15 21:02:16,199] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:16,201] INFO: Processing case number: G.R. No. 119253 in month April, year 1997
# [2024-11-15 21:02:16,552] INFO: Saved case data for G.R. No. 119253 in month April, year 1997
# [2024-11-15 21:02:17,559] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:17,560] INFO: Processing case number: G.R. No. 121313 in month April, year 1997
# [2024-11-15 21:02:17,892] INFO: Saved case data for G.R. No. 121313 in month April, year 1997
# [2024-11-15 21:02:18,897] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:18,899] INFO: Processing case number: G.R. No. 123462 in month April, year 1997
# [2024-11-15 21:02:19,177] INFO: Saved case data for G.R. No. 123462 in month April, year 1997
# [2024-11-15 21:02:20,182] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:20,183] INFO: Processing case number: G.R. Nos. 120835-40 in month April, year 1997
# [2024-11-15 21:02:20,538] INFO: Saved case data for G.R. Nos. 120835-40 in month April, year 1997
# [2024-11-15 21:02:21,542] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:21,543] INFO: Processing case number: G.R. No. 108451 in month April, year 1997
# [2024-11-15 21:02:22,197] INFO: Saved case data for G.R. No. 108451 in month April, year 1997
# [2024-11-15 21:02:23,199] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:23,201] INFO: Processing case number: G.R. No. 113790 in month April, year 1997
# [2024-11-15 21:02:23,545] INFO: Saved case data for G.R. No. 113790 in month April, year 1997
# [2024-11-15 21:02:24,551] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:24,552] INFO: Processing case number: G.R. No. 116808 in month April, year 1997
# [2024-11-15 21:02:24,904] INFO: Saved case data for G.R. No. 116808 in month April, year 1997
# [2024-11-15 21:02:25,910] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:25,911] INFO: Processing case number: G.R. No. 119072 in month April, year 1997
# [2024-11-15 21:02:26,284] INFO: Saved case data for G.R. No. 119072 in month April, year 1997
# [2024-11-15 21:02:27,286] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:27,287] INFO: Processing case number: G.R. No. 82562 in month April, year 1997
# [2024-11-15 21:02:27,628] INFO: Saved case data for G.R. No. 82562 in month April, year 1997
# [2024-11-15 21:02:28,630] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:28,632] INFO: Processing case number: G.R. No. 108033 in month April, year 1997
# [2024-11-15 21:02:28,914] INFO: Saved case data for G.R. No. 108033 in month April, year 1997
# [2024-11-15 21:02:29,920] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:29,921] INFO: Processing case number: G.R. No. 115019 in month April, year 1997
# [2024-11-15 21:02:30,219] INFO: Saved case data for G.R. No. 115019 in month April, year 1997
# [2024-11-15 21:02:31,221] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:31,222] INFO: Processing case number: G.R. No. 116807 in month April, year 1997
# [2024-11-15 21:02:31,542] INFO: Saved case data for G.R. No. 116807 in month April, year 1997
# [2024-11-15 21:02:32,548] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:32,550] INFO: Processing case number: G.R. No. 119043 in month April, year 1997
# [2024-11-15 21:02:32,906] INFO: Saved case data for G.R. No. 119043 in month April, year 1997
# [2024-11-15 21:02:33,910] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:33,911] INFO: Processing case number: G.R. No. 117407 in month April, year 1997
# [2024-11-15 21:02:34,286] INFO: Saved case data for G.R. No. 117407 in month April, year 1997
# [2024-11-15 21:02:35,291] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:35,292] INFO: Processing case number: G.R. No. 117473 in month April, year 1997
# [2024-11-15 21:02:35,614] INFO: Saved case data for G.R. No. 117473 in month April, year 1997
# [2024-11-15 21:02:36,616] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:36,618] INFO: Processing case number: G.R. No. 115879 in month April, year 1997
# [2024-11-15 21:02:37,020] INFO: Saved case data for G.R. No. 115879 in month April, year 1997
# [2024-11-15 21:02:38,027] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:38,028] INFO: Processing case number: G.R. No. 118691 in month April, year 1997
# [2024-11-15 21:02:38,373] INFO: Saved case data for G.R. No. 118691 in month April, year 1997
# [2024-11-15 21:02:39,380] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:39,382] INFO: Processing case number: G.R. No. 119243 in month April, year 1997
# [2024-11-15 21:02:39,769] INFO: Saved case data for G.R. No. 119243 in month April, year 1997
# [2024-11-15 21:02:40,775] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:40,777] INFO: Processing case number: G.R. No. 121397 in month April, year 1997
# [2024-11-15 21:02:41,094] INFO: Saved case data for G.R. No. 121397 in month April, year 1997
# [2024-11-15 21:02:42,100] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:42,102] INFO: Processing case number: A.C. No. 1370 in month April, year 1997
# [2024-11-15 21:02:42,457] INFO: Saved case data for A.C. No. 1370 in month April, year 1997
# [2024-11-15 21:02:43,464] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:43,465] INFO: Processing case number: A.M. No. 96-1-25-RTC in month April, year 1997
# [2024-11-15 21:02:43,820] INFO: Saved case data for A.M. No. 96-1-25-RTC in month April, year 1997
# [2024-11-15 21:02:44,826] INFO: Processing case number: A.M. No. MTJ-94-989 in month April, year 1997
# [2024-11-15 21:02:45,191] INFO: Saved case data for A.M. No. MTJ-94-989 in month April, year 1997
# [2024-11-15 21:02:46,198] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:46,199] INFO: Processing case number: A.M. No. RTJ-96-1349 in month April, year 1997
# [2024-11-15 21:02:46,624] INFO: Saved case data for A.M. No. RTJ-96-1349 in month April, year 1997
# [2024-11-15 21:02:47,630] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:47,632] INFO: Processing case number: G.R. No. 102942 in month April, year 1997
# [2024-11-15 21:02:48,013] INFO: Saved case data for G.R. No. 102942 in month April, year 1997
# [2024-11-15 21:02:49,019] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">Separate Opinion<br/><a href="gr_102942_regalado.html">Justice Regalado<a xref="pdf/gr_102942_regalado.pdf"><img src="../../../imgs/_p.png"/></a>
# <br/><a class="vs">Separate Opinion<br/><a href="gr_102942_vitug.html">Justice Vitug<a xref="pdf/gr_102942_vitug.pdf"><img src="../../../imgs/_p.png"/></a>
# </a></a></a></a>
# [2024-11-15 21:02:49,021] INFO: Processing case number: Justice Regalado
# Separate OpinionJustice Vitug
#  in month April, year 1997
# [2024-11-15 21:02:49,352] INFO: Saved case data for Justice Regalado
# Separate OpinionJustice Vitug
#  in month April, year 1997
# [2024-11-15 21:02:50,357] WARNING: Skipping invalid link in month April, year 1997: <a xref="pdf/gr_102942_regalado.pdf"><img src="../../../imgs/_p.png"/></a>
# [2024-11-15 21:02:50,359] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">Separate Opinion<br/><a href="gr_102942_vitug.html">Justice Vitug<a xref="pdf/gr_102942_vitug.pdf"><img src="../../../imgs/_p.png"/></a>
# </a></a>
# [2024-11-15 21:02:50,360] INFO: Processing case number: Justice Vitug
#  in month April, year 1997
# [2024-11-15 21:02:50,682] INFO: Saved case data for Justice Vitug
#  in month April, year 1997
# [2024-11-15 21:02:51,688] WARNING: Skipping invalid link in month April, year 1997: <a xref="pdf/gr_102942_vitug.pdf"><img src="../../../imgs/_p.png"/></a>
# [2024-11-15 21:02:51,690] INFO: Processing case number: G.R. No. 103595 in month April, year 1997
# [2024-11-15 21:02:52,055] INFO: Saved case data for G.R. No. 103595 in month April, year 1997
# [2024-11-15 21:02:53,059] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:53,061] INFO: Processing case number: G.R. No. 105292 in month April, year 1997
# [2024-11-15 21:02:53,455] INFO: Saved case data for G.R. No. 105292 in month April, year 1997
# [2024-11-15 21:02:54,461] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:54,462] INFO: Processing case number: G.R. No. 107845 in month April, year 1997
# [2024-11-15 21:02:54,817] INFO: Saved case data for G.R. No. 107845 in month April, year 1997
# [2024-11-15 21:02:55,823] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:55,825] INFO: Processing case number: G.R. No. 107846 in month April, year 1997
# [2024-11-15 21:02:56,112] INFO: Saved case data for G.R. No. 107846 in month April, year 1997
# [2024-11-15 21:02:57,113] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:57,115] INFO: Processing case number: G.R. No. 108613 in month April, year 1997
# [2024-11-15 21:02:57,494] INFO: Saved case data for G.R. No. 108613 in month April, year 1997
# [2024-11-15 21:02:58,500] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:58,502] INFO: Processing case number: G.R. No. 109205 in month April, year 1997
# [2024-11-15 21:02:58,876] INFO: Saved case data for G.R. No. 109205 in month April, year 1997
# [2024-11-15 21:02:59,882] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:02:59,884] INFO: Processing case number: G.R. No. 110610 in month April, year 1997
# [2024-11-15 21:03:00,266] INFO: Saved case data for G.R. No. 110610 in month April, year 1997
# [2024-11-15 21:03:01,272] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:01,275] INFO: Processing case number: G.R. No. 110829 in month April, year 1997
# [2024-11-15 21:03:01,644] INFO: Saved case data for G.R. No. 110829 in month April, year 1997
# [2024-11-15 21:03:02,650] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:02,652] INFO: Processing case number: G.R. No. 110872 in month April, year 1997
# [2024-11-15 21:03:03,032] INFO: Saved case data for G.R. No. 110872 in month April, year 1997
# [2024-11-15 21:03:04,036] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:04,038] INFO: Processing case number: G.R. No. 112948 in month April, year 1997
# [2024-11-15 21:03:04,391] INFO: Saved case data for G.R. No. 112948 in month April, year 1997
# [2024-11-15 21:03:05,397] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:05,399] INFO: Processing case number: G.R. No. 113558 in month April, year 1997
# [2024-11-15 21:03:05,728] INFO: Saved case data for G.R. No. 113558 in month April, year 1997
# [2024-11-15 21:03:06,734] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:06,735] INFO: Processing case number: G.R. No. 115077 in month April, year 1997
# [2024-11-15 21:03:07,066] INFO: Saved case data for G.R. No. 115077 in month April, year 1997
# [2024-11-15 21:03:08,072] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:08,074] INFO: Processing case number: G.R. No. 115349 in month April, year 1997
# [2024-11-15 21:03:08,485] INFO: Saved case data for G.R. No. 115349 in month April, year 1997
# [2024-11-15 21:03:09,491] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:09,493] INFO: Processing case number: G.R. No. 117010 in month April, year 1997
# [2024-11-15 21:03:09,862] INFO: Saved case data for G.R. No. 117010 in month April, year 1997
# [2024-11-15 21:03:10,869] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:10,871] INFO: Processing case number: G.R. No. 117818 in month April, year 1997
# [2024-11-15 21:03:11,979] INFO: Saved case data for G.R. No. 117818 in month April, year 1997
# [2024-11-15 21:03:12,985] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:12,988] INFO: Processing case number: G.R. No. 118506 in month April, year 1997
# [2024-11-15 21:03:14,626] INFO: Saved case data for G.R. No. 118506 in month April, year 1997
# [2024-11-15 21:03:15,632] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:15,634] INFO: Processing case number: G.R. No. 119308 in month April, year 1997
# [2024-11-15 21:03:16,094] INFO: Saved case data for G.R. No. 119308 in month April, year 1997
# [2024-11-15 21:03:17,100] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:17,102] INFO: Processing case number: G.R. No. 120408 in month April, year 1997
# [2024-11-15 21:03:17,463] INFO: Saved case data for G.R. No. 120408 in month April, year 1997
# [2024-11-15 21:03:18,466] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:18,468] INFO: Processing case number: G.R. No. 120941 in month April, year 1997
# [2024-11-15 21:03:18,747] INFO: Saved case data for G.R. No. 120941 in month April, year 1997
# [2024-11-15 21:03:19,754] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:19,756] INFO: Processing case number: G.R. No. 123230 in month April, year 1997
# [2024-11-15 21:03:20,202] INFO: Saved case data for G.R. No. 123230 in month April, year 1997
# [2024-11-15 21:03:21,208] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:21,209] INFO: Processing case number: G.R. No. 124169 in month April, year 1997
# [2024-11-15 21:03:21,528] INFO: Saved case data for G.R. No. 124169 in month April, year 1997
# [2024-11-15 21:03:22,534] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">Concurring Opinion<br/><a href="gr_124169_vitug.html">Justice Vitug<a xref="pdf/gr_124169_vitug.pdf"><img src="../../../imgs/_p.png"/></a>
# </a></a>
# [2024-11-15 21:03:22,535] INFO: Processing case number: Justice Vitug
#  in month April, year 1997
# [2024-11-15 21:03:22,816] INFO: Saved case data for Justice Vitug
#  in month April, year 1997
# [2024-11-15 21:03:23,823] WARNING: Skipping invalid link in month April, year 1997: <a xref="pdf/gr_124169_vitug.pdf"><img src="../../../imgs/_p.png"/></a>
# [2024-11-15 21:03:23,825] INFO: Processing case number: G.R. No. 124893 in month April, year 1997
# [2024-11-15 21:03:24,255] INFO: Saved case data for G.R. No. 124893 in month April, year 1997
# [2024-11-15 21:03:25,261] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:25,264] INFO: Processing case number: G.R. Nos. 110999 & 111000 in month April, year 1997
# [2024-11-15 21:03:25,643] INFO: Saved case data for G.R. Nos. 110999 & 111000 in month April, year 1997
# [2024-11-15 21:03:26,649] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:26,651] INFO: Processing case number: G.R. Nos. 113908 & 114819 in month April, year 1997
# [2024-11-15 21:03:27,050] INFO: Saved case data for G.R. Nos. 113908 & 114819 in month April, year 1997
# [2024-11-15 21:03:28,056] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:28,058] INFO: Processing case number: G.R. Nos. 72744-45 in month April, year 1997
# [2024-11-15 21:03:28,496] INFO: Saved case data for G.R. Nos. 72744-45 in month April, year 1997
# [2024-11-15 21:03:29,502] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:29,504] INFO: Processing case number: G.R. No. 126496 in month April, year 1997
# [2024-11-15 21:03:29,936] INFO: Saved case data for G.R. No. 126496 in month April, year 1997
# [2024-11-15 21:03:30,942] WARNING: Skipping invalid link in month April, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:30,943] INFO: Processing case number:  in month April, year 1997
# [2024-11-15 21:03:30,945] WARNING: Error fetching case data from javascript:history.back(1): No connection adapters were found for 'javascript:history.back(1)'. Retrying 2 more times...
# [2024-11-15 21:03:30,947] WARNING: Error fetching case data from javascript:history.back(1): No connection adapters were found for 'javascript:history.back(1)'. Retrying 1 more times...
# [2024-11-15 21:03:30,949] WARNING: Error fetching case data from javascript:history.back(1): No connection adapters were found for 'javascript:history.back(1)'. Retrying 0 more times...
# [2024-11-15 21:03:30,950] ERROR: Failed to fetch case data after retries: javascript:history.back(1)
# [2024-11-15 21:03:30,951] WARNING: Skipping case number:  as no data was found
# [2024-11-15 21:03:31,957] INFO: Processing case number:  in month April, year 1997
# [2024-11-15 21:03:32,327] WARNING: Skipping case number:  as no data was found
# [2024-11-15 21:03:33,334] INFO: Starting processing for month: August of year 1997
# [2024-11-15 21:03:33,713] WARNING: Skipping invalid link in month August, year 1997: <a name="top"></a>
# [2024-11-15 21:03:33,714] INFO: Processing case number: G.R. No. 112354 in month August, year 1997
# [2024-11-15 21:03:34,025] INFO: Saved case data for G.R. No. 112354 in month August, year 1997
# [2024-11-15 21:03:35,031] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:35,032] INFO: Processing case number: G.R. No. 115903 in month August, year 1997
# [2024-11-15 21:03:35,387] INFO: Saved case data for G.R. No. 115903 in month August, year 1997
# [2024-11-15 21:03:36,393] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:36,395] INFO: Processing case number: G.R. No. 106194 in month August, year 1997
# [2024-11-15 21:03:36,649] INFO: Saved case data for G.R. No. 106194 in month August, year 1997
# [2024-11-15 21:03:37,655] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:37,657] INFO: Processing case number: G.R. No. 117188 in month August, year 1997
# [2024-11-15 21:03:38,007] INFO: Saved case data for G.R. No. 117188 in month August, year 1997
# [2024-11-15 21:03:39,014] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:39,015] INFO: Processing case number: G.R. No. 121275 in month August, year 1997
# [2024-11-15 21:03:39,291] INFO: Saved case data for G.R. No. 121275 in month August, year 1997
# [2024-11-15 21:03:40,298] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:40,300] INFO: Processing case number: G.R. No. 122391 in month August, year 1997
# [2024-11-15 21:03:40,729] INFO: Saved case data for G.R. No. 122391 in month August, year 1997
# [2024-11-15 21:03:41,734] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:41,736] INFO: Processing case number: A.M. No. RTJ-95-1303 in month August, year 1997
# [2024-11-15 21:03:42,113] INFO: Saved case data for A.M. No. RTJ-95-1303 in month August, year 1997
# [2024-11-15 21:03:43,116] INFO: Processing case number: G.R. No. 107307 in month August, year 1997
# [2024-11-15 21:03:43,473] INFO: Saved case data for G.R. No. 107307 in month August, year 1997
# [2024-11-15 21:03:44,479] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:44,481] INFO: Processing case number: G.R. No. 108234 in month August, year 1997
# [2024-11-15 21:03:44,938] INFO: Saved case data for G.R. No. 108234 in month August, year 1997
# [2024-11-15 21:03:45,945] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:45,947] INFO: Processing case number: G.R. No. 109617 in month August, year 1997
# [2024-11-15 21:03:46,445] INFO: Saved case data for G.R. No. 109617 in month August, year 1997
# [2024-11-15 21:03:47,451] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:47,453] INFO: Processing case number: G.R. No. 111824 in month August, year 1997
# [2024-11-15 21:03:47,819] INFO: Saved case data for G.R. No. 111824 in month August, year 1997
# [2024-11-15 21:03:48,825] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:48,827] INFO: Processing case number: G.R. No. 120988 in month August, year 1997
# [2024-11-15 21:03:49,202] INFO: Saved case data for G.R. No. 120988 in month August, year 1997
# [2024-11-15 21:03:50,209] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:50,210] INFO: Processing case number: G.R. No. 121210 in month August, year 1997
# [2024-11-15 21:03:50,578] INFO: Saved case data for G.R. No. 121210 in month August, year 1997
# [2024-11-15 21:03:51,583] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:51,584] INFO: Processing case number: G.R. No. 121983 in month August, year 1997
# [2024-11-15 21:03:51,908] INFO: Saved case data for G.R. No. 121983 in month August, year 1997
# [2024-11-15 21:03:52,914] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:52,916] INFO: Processing case number: G.R. No. 121983 in month August, year 1997
# [2024-11-15 21:03:53,301] INFO: Saved case data for G.R. No. 121983 in month August, year 1997
# [2024-11-15 21:03:54,307] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:54,309] INFO: Processing case number: G.R. No. 123240 in month August, year 1997
# [2024-11-15 21:03:54,638] INFO: Saved case data for G.R. No. 123240 in month August, year 1997
# [2024-11-15 21:03:55,645] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:55,647] INFO: Processing case number: G.R. No. 95089 in month August, year 1997
# [2024-11-15 21:03:56,079] INFO: Saved case data for G.R. No. 95089 in month August, year 1997
# [2024-11-15 21:03:57,083] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:57,085] INFO: Processing case number: G.R. No. 97898 in month August, year 1997
# [2024-11-15 21:03:57,409] INFO: Saved case data for G.R. No. 97898 in month August, year 1997
# [2024-11-15 21:03:58,415] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:58,419] INFO: Processing case number: G.R. No. 99355 in month August, year 1997
# [2024-11-15 21:03:58,782] INFO: Saved case data for G.R. No. 99355 in month August, year 1997
# [2024-11-15 21:03:59,788] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:03:59,791] INFO: Processing case number: G.R. No. 110129 in month August, year 1997
# [2024-11-15 21:04:00,103] INFO: Saved case data for G.R. No. 110129 in month August, year 1997
# [2024-11-15 21:04:01,105] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:04:01,107] INFO: Processing case number: G.R. No. 110397 in month August, year 1997
# [2024-11-15 21:04:01,532] INFO: Saved case data for G.R. No. 110397 in month August, year 1997
# [2024-11-15 21:04:02,538] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:04:02,540] INFO: Processing case number: G.R. No. 127255 in month August, year 1997
# [2024-11-15 21:04:02,984] INFO: Saved case data for G.R. No. 127255 in month August, year 1997
# [2024-11-15 21:04:03,990] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">Concurring Opinion<br/><a href="gr_127255_vitug.html">Justice Vitug<a xref="pdf/gr_127255_vitug.pdf"><img src="../../../imgs/_p.png"/></a>
# <br/><a class="vs">Separate Opinion<br/><a href="gr_127255_romero.html">Justice Romero<a xref="pdf/gr_127255_romero.pdf"><img src="../../../imgs/_p.png"/></a>
# <br/><a class="vs">Concurring and Dissenting Opinion<br/><a href="gr_127255_puno.html">Justice Puno<a xref="pdf/gr_127255_puno.pdf"><img src="../../../imgs/_p.png"/></a>
# </a></a></a></a></a></a>
# [2024-11-15 21:04:03,991] INFO: Processing case number: Justice Vitug
# Separate OpinionJustice Romero
# Concurring and Dissenting OpinionJustice Puno
#  in month August, year 1997
# [2024-11-15 21:04:04,252] INFO: Saved case data for Justice Vitug
# Separate OpinionJustice Romero
# Concurring and Dissenting OpinionJustice Puno
#  in month August, year 1997
# [2024-11-15 21:04:05,255] WARNING: Skipping invalid link in month August, year 1997: <a xref="pdf/gr_127255_vitug.pdf"><img src="../../../imgs/_p.png"/></a>
# [2024-11-15 21:04:05,257] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">Separate Opinion<br/><a href="gr_127255_romero.html">Justice Romero<a xref="pdf/gr_127255_romero.pdf"><img src="../../../imgs/_p.png"/></a>
# <br/><a class="vs">Concurring and Dissenting Opinion<br/><a href="gr_127255_puno.html">Justice Puno<a xref="pdf/gr_127255_puno.pdf"><img src="../../../imgs/_p.png"/></a>
# </a></a></a></a>
# [2024-11-15 21:04:05,258] INFO: Processing case number: Justice Romero
# Concurring and Dissenting OpinionJustice Puno
#  in month August, year 1997
# [2024-11-15 21:04:05,539] INFO: Saved case data for Justice Romero
# Concurring and Dissenting OpinionJustice Puno
#  in month August, year 1997
# [2024-11-15 21:04:06,541] WARNING: Skipping invalid link in month August, year 1997: <a xref="pdf/gr_127255_romero.pdf"><img src="../../../imgs/_p.png"/></a>
# [2024-11-15 21:04:06,542] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">Concurring and Dissenting Opinion<br/><a href="gr_127255_puno.html">Justice Puno<a xref="pdf/gr_127255_puno.pdf"><img src="../../../imgs/_p.png"/></a>
# </a></a>
# [2024-11-15 21:04:06,544] INFO: Processing case number: Justice Puno
#  in month August, year 1997
# [2024-11-15 21:04:06,980] INFO: Saved case data for Justice Puno
#  in month August, year 1997
# [2024-11-15 21:04:07,986] WARNING: Skipping invalid link in month August, year 1997: <a xref="pdf/gr_127255_puno.pdf"><img src="../../../imgs/_p.png"/></a>
# [2024-11-15 21:04:07,986] INFO: Processing case number: G.R. Nos. 116307-10 in month August, year 1997
# [2024-11-15 21:04:08,342] INFO: Saved case data for G.R. Nos. 116307-10 in month August, year 1997
# [2024-11-15 21:04:09,346] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:04:09,347] INFO: Processing case number: A.M. No. P-96-1219 in month August, year 1997
# [2024-11-15 21:04:09,735] INFO: Saved case data for A.M. No. P-96-1219 in month August, year 1997
# [2024-11-15 21:04:10,741] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:04:10,743] INFO: Processing case number: G.R. No. 109645 in month August, year 1997
# [2024-11-15 21:04:11,183] INFO: Saved case data for G.R. No. 109645 in month August, year 1997
# [2024-11-15 21:04:12,189] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:04:12,190] INFO: Processing case number: G.R. No. 110399 in month August, year 1997
# [2024-11-15 21:04:12,530] INFO: Saved case data for G.R. No. 110399 in month August, year 1997
# [2024-11-15 21:04:13,535] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:04:13,544] INFO: Processing case number: G.R. No. 112180 in month August, year 1997
# [2024-11-15 21:04:13,899] INFO: Saved case data for G.R. No. 112180 in month August, year 1997
# [2024-11-15 21:04:14,900] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:04:14,901] INFO: Processing case number: G.R. No. 115844 in month August, year 1997
# [2024-11-15 21:04:15,219] INFO: Saved case data for G.R. No. 115844 in month August, year 1997
# [2024-11-15 21:04:16,226] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:04:16,227] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">Dissenting Opinion<br/><a href="gr_115844_davide.html">Justice Davide<a xref="pdf/gr_115844_davide.pdf"><img src="../../../imgs/_p.png"/></a>
# </a></a>
# [2024-11-15 21:04:16,228] INFO: Processing case number: Justice Davide
#  in month August, year 1997
# [2024-11-15 21:04:16,532] INFO: Saved case data for Justice Davide
#  in month August, year 1997
# [2024-11-15 21:04:17,536] WARNING: Skipping invalid link in month August, year 1997: <a xref="pdf/gr_115844_davide.pdf"><img src="../../../imgs/_p.png"/></a>
# [2024-11-15 21:04:17,537] INFO: Processing case number: G.R. No. 117398 in month August, year 1997
# [2024-11-15 21:04:17,896] INFO: Saved case data for G.R. No. 117398 in month August, year 1997
# [2024-11-15 21:04:18,902] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:04:18,903] INFO: Processing case number: G.R. No. 120064 in month August, year 1997
# [2024-11-15 21:04:19,249] INFO: Saved case data for G.R. No. 120064 in month August, year 1997
# [2024-11-15 21:04:20,255] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:04:20,256] INFO: Processing case number: G.R. No. 121377 in month August, year 1997
# [2024-11-15 21:04:20,595] INFO: Saved case data for G.R. No. 121377 in month August, year 1997
# [2024-11-15 21:04:21,597] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:04:21,598] INFO: Processing case number: G.R. No. 121466 in month August, year 1997
# [2024-11-15 21:04:23,321] INFO: Saved case data for G.R. No. 121466 in month August, year 1997
# [2024-11-15 21:04:24,323] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:04:24,325] INFO: Processing case number: G.R. No. 123290 in month August, year 1997
# [2024-11-15 21:04:24,722] INFO: Saved case data for G.R. No. 123290 in month August, year 1997
# [2024-11-15 21:04:25,725] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:04:25,726] INFO: Processing case number: G.R. Nos. 111066-67 in month August, year 1997
# [2024-11-15 21:04:26,058] INFO: Saved case data for G.R. Nos. 111066-67 in month August, year 1997
# [2024-11-15 21:04:27,060] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:04:27,062] INFO: Processing case number: A.M. No. P-97-1234 in month August, year 1997
# [2024-11-15 21:04:27,348] INFO: Saved case data for A.M. No. P-97-1234 in month August, year 1997
# [2024-11-15 21:04:28,355] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:04:28,358] INFO: Processing case number: A.M. No. RTJ-96-1350 in month August, year 1997
# [2024-11-15 21:04:28,687] INFO: Saved case data for A.M. No. RTJ-96-1350 in month August, year 1997
# [2024-11-15 21:04:29,693] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:04:29,695] INFO: Processing case number: G.R. No. 101832 in month August, year 1997
# [2024-11-15 21:04:30,062] INFO: Saved case data for G.R. No. 101832 in month August, year 1997
# [2024-11-15 21:04:31,063] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:04:31,066] INFO: Processing case number: G.R. No. 113245-47 in month August, year 1997
# [2024-11-15 21:04:31,455] INFO: Saved case data for G.R. No. 113245-47 in month August, year 1997
# [2024-11-15 21:04:32,461] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:04:32,462] INFO: Processing case number: G.R. No. 115527 in month August, year 1997
# [2024-11-15 21:04:32,789] INFO: Saved case data for G.R. No. 115527 in month August, year 1997
# [2024-11-15 21:04:33,796] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">vs.</a>
# [2024-11-15 21:04:33,797] INFO: Processing case number: G.R. No. 117682 in month August, year 1997
# [2024-11-15 21:04:34,213] INFO: Saved case data for G.R. No. 117682 in month August, year 1997
# [2024-11-15 21:04:35,222] WARNING: Skipping invalid link in month August, year 1997: <a class="vs">Dissenting Opinion<br/><a href="gr_117682_davide.html">Justice Davide, Jr.<a xref="pdf/gr_117682_davide.pdf"><img src="../../../imgs/_p.png"/></a>
# <br/><a class="vs">Concurring Opinion<br/><a href="gr_117682_francisco.html">Justice Francisco<a xref="pdf/gr_117682_francisco.pdf"><img src="../../../imgs/_p.png"/></a>
# <br/><a class="vs">Dissenting Opinion<br/><a href="gr_117682_regalado.html">Justice Regalado<a xref="pdf/gr_117682_regalado.pdf"><img src="../../../imgs/_p.png"/></a>
# <tr class="xy"><td>
# <a href="gr_118815_1997.html">G.R. No. 118815</a><br/>August 18, 1997
# </td><td>
# People of the Philippines <a class="vs">vs.</a> Anita Melgar — Mercader Y Tongco
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_119252_1997.html">G.R. No. 119252</a><br/>August 18, 1997
# </td><td>
# Commissioner of Internal Revenue, et al. <a class="vs">vs.</a> Apolinario B. Santos, et al.
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_119288_1997.html">G.R. No. 119288</a><br/>August 18, 1997
# </td><td>
# Republic of the Philippines <a class="vs">vs.</a> Court of Appeals, et al.
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_119368_1997.html">G.R. No. 119368</a><br/>August 18, 1997
# </td><td>
# People of the Philippines <a class="vs">vs.</a> Marcelino Erardo
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_119696_1997.html">G.R. No. 119696</a><br/>August 18, 1997
# </td><td>
# People of the Philippines <a class="vs">vs.</a> Razul Guiamil Y Angkat, et al.
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_120256_1997.html">G.R. No. 120256</a><br/>August 18, 1997
# </td><td>
# Hermito Cabcaban <a class="vs">vs.</a> National Labor Relations Commission, et al.
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_123276_1997.html">G.R. No. 123276</a><br/>August 18, 1997
# </td><td>
# Mario Tiu, et al. <a class="vs">vs.</a> National Labor Relations Commission, et al.
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_124520_1997.html">G.R. No. 124520</a><br/>August 18, 1997
# </td><td>
# Nilo Cha, et al. <a class="vs">vs.</a> Court of Appeals, et al.
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_95449_1997.html">G.R. No. 95449</a><br/>August 18, 1997
# </td><td>
# Philippine-Singapore Transport Services, Inc. <a class="vs">vs.</a> National Labor Relations Commission, et al.
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_95523_1997.html">G.R. No. 95523</a><br/>August 18, 1997
# </td><td>
# Reynaldo R. Gonzales <a class="vs">vs.</a> Court of Appeals, et al.
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_98107_1997.html">G.R. No. 98107</a><br/>August 18, 1997
# </td><td>
# Benjamin C. Juco <a class="vs">vs.</a> National Labor Relations Commission, et al.
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_108611_1997.html">G.R. No. 108611</a><br/>August 20, 1997
# </td><td>
# People of the Philippines <a class="vs">vs.</a> Jose Asto, et al.
# </td></tr>
# <tr class="xy"><td>
# <a href="am_93_9_1237_1997.html">A.M. No. 93-9-1237-RTC</a><br/>August 21, 1997
# </td><td>
# Re: Loss of Court Exhibits
# </td></tr>
# <tr class="xy"><td>
# <a href="am_96_11_402_1997.html">A.M. No. 96-11-402-RTC</a><br/>August 21, 1997
# </td><td>
# Re: Report on the Judicial Audit
# </td></tr>
# <tr class="xy"><td>
# <a href="am_97_2_12_1997.html">A.M. No. 97-2-12-MTC</a><br/>August 21, 1997
# </td><td>
# Re: Issuance of Subpoena to Prisoner
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_101829_1997.html">G.R. No. 101829</a><br/>August 21, 1997
# </td><td>
# People of the Philippines <a class="vs">vs.</a> Bonifacio Zamora, et al.
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_102018_1997.html">G.R. No. 102018</a><br/>August 21, 1997
# </td><td>
# People of the Philippines <a class="vs">vs.</a> Jerry Gabayron
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_103959_1997.html">G.R. No. 103959</a><br/>August 21, 1997
# </td><td>
# Regalado Santiago, et al. <a class="vs">vs.</a> Court of Appeals, et al.
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_108183_85_1997.html">G.R. No. 108183-85</a><br/>August 21, 1997
# </td><td>
# People of the Philippines <a class="vs">vs.</a> Dione Palomar, et al.
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_110249_1997.html">G.R. No. 110249</a><br/>August 21, 1997
# </td><td>
# Alfredo Tano, et al. <a class="vs">vs.</a> Salvador P. Socrates, et al.
# <br/><a class="vs">Dissenting Opinion<br/><a href="gr_110249_bellosillo.html">Justice Bellosillo<a xref="pdf/gr_110249_bellosillo.pdf"><img src="../../../imgs/_p.png"/></a>
# <br/><a class="vs">Concurring Opinion<br/><a href="gr_110249_mendoza.html">Justice Mendoza<a xref="pdf/gr_110249_mendoza.pdf"><img src="../../../imgs/_p.png"/></a>
# </a></a></a></a></td></tr>
# <tr class="xy"><td>
# <a href="gr_112513_1997.html">G.R. No. 112513</a><br/>August 21, 1997
# </td><td>
# Edgar R. Del Castillo <a class="vs">vs.</a> Civil Service Commission, et al.
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_113032_1997.html">G.R. No. 113032</a><br/>August 21, 1997
# </td><td>
# Western Institute of Technology, Inc., et al. <a class="vs">vs.</a> Ricardo T. Salas, et al.
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_116294_1997.html">G.R. No. 116294</a><br/>August 21, 1997
# </td><td>
# People of the Philippines <a class="vs">vs.</a> Antonio Chavez Y Estamante, et al.
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_120691_1997.html">G.R. No. 120691</a><br/>August 21, 1997
# </td><td>
# Bionic Heavy Equipments, Inc., et al. <a class="vs">vs.</a> National Labor Relations Commission, et al.
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_123053_1997.html">G.R. No. 123053</a><br/>August 21, 1997
# </td><td>
# People of the Philippines <a class="vs">vs.</a> Leonardo L. Carizo, et al.
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_123492_1997.html">G.R. No. 123492</a><br/>August 21, 1997
# </td><td>
# Danilo A. Yap <a class="vs">vs.</a> National Labor Relations Commission, et al.
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_126749_1997.html">G.R. No. 126749</a><br/>August 21, 1997
# </td><td>
# Eriberto M. Suson <a class="vs">vs.</a> Court of Appeals, et al.
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_127896_1997.html">G.R. No. 127896</a><br/>August 21, 1997
# </td><td>
# Adriano A. Arellano, Jr. <a class="vs">vs.</a> National Labor Relations Commission, et al.
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_94723_1997.html">G.R. No. 94723</a><br/>August 21, 1997
# </td><td>
# Karen E. Salvacion, et al. <a class="vs">vs.</a> Central Bank of the Philippines, et al.
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_96176_1997.html">G.R. No. 96176</a><br/>August 21, 1997
# </td><td>
# People of the Philippines <a class="vs">vs.</a> Zenaida Isla
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_116602_03_1997.html">G.R. Nos. 116602-03</a><br/>August 21, 1997
# </td><td>
# Carmelita Sarao <a class="vs">vs.</a> Court of Appeals, et al.
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_109578_1997.html">G.R. No. 109578</a><br/>August 27, 1997
# </td><td>
# People of the Philippines <a class="vs">vs.</a> Ronaldo S. Fabro, et al.
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_115581_1997.html">G.R. No. 115581</a><br/>August 29, 1997
# </td><td>
# People of the Philippines <a class="vs">vs.</a> Vacita Latura Jones
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_119332_1997.html">G.R. No. 119332</a><br/>August 29, 1997
# </td><td>
# People of the Philippines <a class="vs">vs.</a> Jack V. Sorrel
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_123581_1997.html">G.R. No. 123581</a><br/>August 29, 1997
# </td><td>
# Rodrigo B. Bangayan, et al. <a class="vs">vs.</a> Court of Appeals, et al.
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_97642_1997.html">G.R. No. 97642</a><br/>August 29, 1997
# </td><td>
# Avon Insurance PLC. British Reserve Insurance Co., Ltd., et al. <a class="vs">vs.</a> Court of Appeals, et al.
# </td></tr>
# <tr class="xy"><td>
# <a href="gr_116744_47_1997.html">G.R. Nos. 116744-47</a><br/>August 29, 1997
# </td><td>
# People of the Philippines <a class="vs">vs.</a> Bernardo "Toldo" Panes, et al.
# </td></tr>
# <tr><td class="id" colspan="2">The Lawphil Project - Arellano Law Foundation, Inc.</td></tr>
# <tr><td><a href="javascript:history.back(1)"><img border="0" src="../../../images/back.gif"/></a><td><a href="#top"><img align="right" border="0" src="../../../images/top.gif"/></a>
# </td></td></tr></a></a></a></a></a></a>
# [2024-11-15 21:04:35,224] INFO: Processing case number: Justice Davide, Jr.
# Concurring OpinionJustice Francisco
# Dissenting OpinionJustice Regalado
#
# G.R. No. 118815August 18, 1997
#
# People of the Philippines vs. Anita Melgar — Mercader Y Tongco
#
#
# G.R. No. 119252August 18, 1997
#
# Commissioner of Internal Revenue, et al. vs. Apolinario B. Santos, et al.
#
#
# G.R. No. 119288August 18, 1997
#
# Republic of the Philippines vs. Court of Appeals, et al.
#
#
# G.R. No. 119368August 18, 1997
#
# People of the Philippines vs. Marcelino Erardo
#
#
# G.R. No. 119696August 18, 1997
#
# People of the Philippines vs. Razul Guiamil Y Angkat, et al.
#
#
# G.R. No. 120256August 18, 1997
#
# Hermito Cabcaban vs. National Labor Relations Commission, et al.
#
#
# G.R. No. 123276August 18, 1997
#
# Mario Tiu, et al. vs. National Labor Relations Commission, et al.
#
#
# G.R. No. 124520August 18, 1997
#
# Nilo Cha, et al. vs. Court of Appeals, et al.
#
#
# G.R. No. 95449August 18, 1997
#
# Philippine-Singapore Transport Services, Inc. vs. National Labor Relations Commission, et al.
#
#
# G.R. No. 95523August 18, 1997
#
# Reynaldo R. Gonzales vs. Court of Appeals, et al.
#
#
# G.R. No. 98107August 18, 1997
#
# Benjamin C. Juco vs. National Labor Relations Commission, et al.
#
#
# G.R. No. 108611August 20, 1997
#
# People of the Philippines vs. Jose Asto, et al.
#
#
# A.M. No. 93-9-1237-RTCAugust 21, 1997
#
# Re: Loss of Court Exhibits
#
#
# A.M. No. 96-11-402-RTCAugust 21, 1997
#
# Re: Report on the Judicial Audit
#
#
# A.M. No. 97-2-12-MTCAugust 21, 1997
#
# Re: Issuance of Subpoena to Prisoner
#
#
# G.R. No. 101829August 21, 1997
#
# People of the Philippines vs. Bonifacio Zamora, et al.
#
#
# G.R. No. 102018August 21, 1997
#
# People of the Philippines vs. Jerry Gabayron
#
#
# G.R. No. 103959August 21, 1997
#
# Regalado Santiago, et al. vs. Court of Appeals, et al.
#
#
# G.R. No. 108183-85August 21, 1997
#
# People of the Philippines vs. Dione Palomar, et al.
#
#
# G.R. No. 110249August 21, 1997
#
# Alfredo Tano, et al. vs. Salvador P. Socrates, et al.
# Dissenting OpinionJustice Bellosillo
# Concurring OpinionJustice Mendoza
#
#
# G.R. No. 112513August 21, 1997
#
# Edgar R. Del Castillo vs. Civil Service Commission, et al.
#
#
# G.R. No. 113032August 21, 1997
#
# Western Institute of Technology, Inc., et al. vs. Ricardo T. Salas, et al.
#
#
# G.R. No. 116294August 21, 1997
#
# People of the Philippines vs. Antonio Chavez Y Estamante, et al.
#
#
# G.R. No. 120691August 21, 1997
#
# Bionic Heavy Equipments, Inc., et al. vs. National Labor Relations Commission, et al.
#
#
# G.R. No. 123053August 21, 1997
#
# People of the Philippines vs. Leonardo L. Carizo, et al.
#
#
# G.R. No. 123492August 21, 1997
#
# Danilo A. Yap vs. National Labor Relations Commission, et al.
#
#
# G.R. No. 126749August 21, 1997
#
# Eriberto M. Suson vs. Court of Appeals, et al.
#
#
# G.R. No. 127896August 21, 1997
#
# Adriano A. Arellano, Jr. vs. National Labor Relations Commission, et al.
#
#
# G.R. No. 94723August 21, 1997
#
# Karen E. Salvacion, et al. vs. Central Bank of the Philippines, et al.
#
#
# G.R. No. 96176August 21, 1997
#
# People of the Philippines vs. Zenaida Isla
#
#
# G.R. Nos. 116602-03August 21, 1997
#
# Carmelita Sarao vs. Court of Appeals, et al.
#
#
# G.R. No. 109578August 27, 1997
#
# People of the Philippines vs. Ronaldo S. Fabro, et al.
#
#
# G.R. No. 115581August 29, 1997
#
# People of the Philippines vs. Vacita Latura Jones
#
#
# G.R. No. 119332August 29, 1997
#
# People of the Philippines vs. Jack V. Sorrel
#
#
# G.R. No. 123581August 29, 1997
#
# Rodrigo B. Bangayan, et al. vs. Court of Appeals, et al.
#
#
# G.R. No. 97642August 29, 1997
#
# Avon Insurance PLC. British Reserve Insurance Co., Ltd., et al. vs. Court of Appeals, et al.
#
#
# G.R. Nos. 116744-47August 29, 1997
#
# People of the Philippines vs. Bernardo "Toldo" Panes, et al.
#
# The Lawphil Project - Arellano Law Foundation, Inc.
#
#  in month August, year 1997
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 167
#     164     logger.info("Completed scraping process.")
#     166 # Run the scraping process
# --> 167 scrape_jurisprudence()
#
# Cell In[3], line 152, in scrape_jurisprudence()
#     148 case_number, title, case_data = scrape_case_data(case_url, year_text, month_text, case_text)
#     150 if case_data:
#     151     # Save case data to a CSV file
# --> 152     with open(csv_file_path, mode="w", newline='', encoding="utf-8", errors="replace") as csv_file:
#     153         writer = csv.writer(csv_file)
#     154         writer.writerow(["Year", "Month", "Case Number", "Title", "Data"])
#
# File ~/scrape/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# OSError: [Errno 63] File name too long: 'Data/Jurisprudence/1997/August/Justice Davide, Jr.\nConcurring OpinionJustice Francisco\nDissenting OpinionJustice Regalado\n\nG.R. No. 118815August 18, 1997\r\n\r\nPeople of the Philippines vs. Anita Melgar — Mercader Y Tongco\r\n\n\nG.R. No. 119252August 18, 1997\r\n\r\nCommissioner of Internal Revenue, et al. vs. Apolinario B. Santos, et al.\r\n\n\nG.R. No. 119288August 18, 1997\r\n\r\nRepublic of the Philippines vs. Court of Appeals, et al.\r\n\n\nG.R. No. 119368August 18, 1997\r\n\r\nPeople of the Philippines vs. Marcelino Erardo\r\n\n\nG.R. No. 119696August 18, 1997\r\n\r\nPeople of the Philippines vs. Razul Guiamil Y Angkat, et al.\r\n\n\nG.R. No. 120256August 18, 1997\r\n\r\nHermito Cabcaban vs. National Labor Relations Commission, et al.\r\n\n\nG.R. No. 123276August 18, 1997\r\n\r\nMario Tiu, et al. vs. National Labor Relations Commission, et al.\r\n\n\nG.R. No. 124520August 18, 1997\r\n\r\nNilo Cha, et al. vs. Court of Appeals, et al.\r\n\n\nG.R. No. 95449August 18, 1997\r\n\r\nPhilippine-Singapore Transport Services, Inc. vs. National Labor Relations Commission, et al.\r\n\n\nG.R. No. 95523August 18, 1997\r\n\r\nReynaldo R. Gonzales vs. Court of Appeals, et al.\r\n\n\nG.R. No. 98107August 18, 1997\r\n\r\nBenjamin C. Juco vs. National Labor Relations Commission, et al.\r\n\n\nG.R. No. 108611August 20, 1997\r\n\r\nPeople of the Philippines vs. Jose Asto, et al.\r\n\n\nA.M. No. 93-9-1237-RTCAugust 21, 1997\r\n\r\nRe_ Loss of Court Exhibits\r\n\n\nA.M. No. 96-11-402-RTCAugust 21, 1997\r\n\r\nRe_ Report on the Judicial Audit\r\n\n\nA.M. No. 97-2-12-MTCAugust 21, 1997\r\n\r\nRe_ Issuance of Subpoena to Prisoner\r\n\n\nG.R. No. 101829August 21, 1997\r\n\r\nPeople of the Philippines vs. Bonifacio Zamora, et al.\r\n\n\nG.R. No. 102018August 21, 1997\r\n\r\nPeople of the Philippines vs. Jerry Gabayron\r\n\n\nG.R. No. 103959August 21, 1997\r\n\r\nRegalado Santiago, et al. vs. Court of Appeals, et al.\r\n\n\nG.R. No. 108183-85August 21, 1997\r\n\r\nPeople of the Philippines vs. Dione Palomar, et al.\r\n\n\nG.R. No. 110249August 21, 1997\r\n\r\nAlfredo Tano, et al. vs. Salvador P. Socrates, et al.\r\nDissenting OpinionJustice Bellosillo\nConcurring OpinionJustice Mendoza\n\n\nG.R. No. 112513August 21, 1997\r\n\r\nEdgar R. Del Castillo vs. Civil Service Commission, et al.\r\n\n\nG.R. No. 113032August 21, 1997\r\n\r\nWestern Institute of Technology, Inc., et al. vs. Ricardo T. Salas, et al.\r\n\n\nG.R. No. 116294August 21, 1997\r\n\r\nPeople of the Philippines vs. Antonio Chavez Y Estamante, et al.\r\n\n\nG.R. No. 120691August 21, 1997\r\n\r\nBionic Heavy Equipments, Inc., et al. vs. National Labor Relations Commission, et al.\r\n\n\nG.R. No. 123053August 21, 1997\r\n\r\nPeople of the Philippines vs. Leonardo L. Carizo, et al.\r\n\n\nG.R. No. 123492August 21, 1997\r\n\r\nDanilo A. Yap vs. National Labor Relations Commission, et al.\r\n\n\nG.R. No. 126749August 21, 1997\r\n\r\nEriberto M. Suson vs. Court of Appeals, et al.\r\n\n\nG.R. No. 127896August 21, 1997\r\n\r\nAdriano A. Arellano, Jr. vs. National Labor Relations Commission, et al.\r\n\n\nG.R. No. 94723August 21, 1997\r\n\r\nKaren E. Salvacion, et al. vs. Central Bank of the Philippines, et al.\r\n\n\nG.R. No. 96176August 21, 1997\r\n\r\nPeople of the Philippines vs. Zenaida Isla\r\n\n\nG.R. Nos. 116602-03August 21, 1997\r\n\r\nCarmelita Sarao vs. Court of Appeals, et al.\r\n\n\nG.R. No. 109578August 27, 1997\r\n\r\nPeople of the Philippines vs. Ronaldo S. Fabro, et al.\r\n\n\nG.R. No. 115581August 29, 1997\r\n\r\nPeople of the Philippines vs. Vacita Latura Jones\r\n\n\nG.R. No. 119332August 29, 1997\r\n\r\nPeople of the Philippines vs. Jack V. Sorrel\r\n\n\nG.R. No. 123581August 29, 1997\r\n\r\nRodrigo B. Bangayan, et al. vs. Court of Appeals, et al.\r\n\n\nG.R. No. 97642August 29, 1997\r\n\r\nAvon Insurance PLC. British Reserve Insurance Co., Ltd., et al. vs. Court of Appeals, et al.\r\n\n\nG.R. Nos. 116744-47August 29, 1997\r\n\r\n ...
