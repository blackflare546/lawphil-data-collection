# %%
import os
import requests
import logging
import pandas as pd
import re
from bs4 import BeautifulSoup

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger()

# Base URL for linking
base_url = "https://lawphil.net/statutes/comacts/"
start_url = "https://lawphil.net/statutes/comacts/comacts.html"

# Directory to save the data files
data_dir = "Data/Statutes/Common Wealth Acts"
os.makedirs(data_dir, exist_ok=True)

def fetch_page(url):
    """Fetches the HTML content of a given URL."""
    try:
        response = requests.get(url)
        response.raise_for_status()
        return response.text
    except requests.RequestException as e:
        logger.error(f"Failed to fetch page: {url}. Error: {e}")
        return None

def parse_main_page(html):
    """Parses the main page to find the desired table with the list of acts."""
    soup = BeautifulSoup(html, 'html.parser')
    table = soup.find('table', {'id': 's-menu'})
    links = []
    
    if not table:
        logger.error("No table with id 's-menu' found on the page.")
        return links
    
    # Process rows within the table
    for row in table.find_all('tr')[1:]:  # Skip the header row
        columns = row.find_all('td')
        if len(columns) < 2:
            continue

        number_link = columns[0].find('a')
        title = columns[1].text.strip()
        
        if number_link and number_link['href']:
            link = number_link['href']
            # Only append valid links (not javascript or empty)
            if link.startswith("javascript"):
                logger.warning(f"Skipping invalid javascript link: {link}")
                continue
            full_link = base_url + link
            links.append((full_link, title))
    
    logger.info(f"Found {len(links)} valid links in the table.")
    return links


def parse_act_page(url):
    """Parses the act page to retrieve the Number, Title, and Data."""
    html = fetch_page(url)
    if not html:
        return None, None, None

    soup = BeautifulSoup(html, 'html.parser')
    blockquote = soup.find('blockquote')
    if not blockquote:
        logger.warning(f"No blockquote found on page: {url}")
        return None, None, None

    paragraphs = blockquote.find_all('p')
    if len(paragraphs) < 2:
        logger.warning(f"Insufficient paragraphs in blockquote at: {url}")
        return None, None, None

    # Clean the 'Number' by removing square brackets and extra spaces
    number = paragraphs[0].text.strip()
    number = re.sub(r'[\[\]]', '', number)  # Remove square brackets

    title = paragraphs[1].text.strip()
    data = blockquote.text.strip()
    
    return number, title, data

def save_to_csv(number, title, data):
    """Saves the act information to a CSV file in the data directory."""
    file_path = os.path.join(data_dir, f"{number}.csv")
    df = pd.DataFrame([[number, title, data]], columns=["Number", "Title", "Data"])
    df.to_csv(file_path, index=False, encoding='utf-8')
    logger.info(f"Data saved to {file_path}")

def main():
    main_page_html = fetch_page(start_url)
    if not main_page_html:
        logger.error("Failed to retrieve main page.")
        return

    act_links = parse_main_page(main_page_html)
    for url, title in act_links:
        logger.info(f"Processing URL: {url}")
        number, title, data = parse_act_page(url)
        if number and title and data:
            save_to_csv(number, title, data)
        else:
            logger.warning(f"Skipping due to incomplete data for URL: {url}")

if __name__ == "__main__":
    main()
# Out:
# 2024-11-14 16:43:12,884 - WARNING - Skipping invalid javascript link: javascript:history.back(1)
# 2024-11-14 16:43:12,884 - INFO - Found 733 valid links in the table.
# 2024-11-14 16:43:12,885 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1946/ca_733_1946.html
# 2024-11-14 16:43:13,334 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 733, July 03, 1946 .csv
# 2024-11-14 16:43:13,334 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1946/ca_732_1946.html
# 2024-11-14 16:43:13,644 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 732, July 03, 1946 .csv
# 2024-11-14 16:43:13,645 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1946/ca_731_1946.html
# 2024-11-14 16:43:13,922 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 731, July 03, 1946 .csv
# 2024-11-14 16:43:13,922 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1946/ca_730_1946.html
# 2024-11-14 16:43:14,467 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 730, July 02, 1946 .csv
# 2024-11-14 16:43:14,468 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1946/ca_729_1946.html
# 2024-11-14 16:43:14,740 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 729, July 02, 1946 .csv
# 2024-11-14 16:43:14,741 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1946/ca_728_1946.html
# 2024-11-14 16:43:14,993 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 728, July 02, 1946 .csv
# 2024-11-14 16:43:14,994 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1946/ca_727_1946.html
# 2024-11-14 16:43:15,263 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 727, January 18, 1946 .csv
# 2024-11-14 16:43:15,264 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1946/ca_726_1946.html
# 2024-11-14 16:43:15,810 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 726, January 15, 1946 .csv
# 2024-11-14 16:43:15,811 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1946/ca_725_1946.html
# 2024-11-14 16:43:16,173 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 725, January 05, 1946 .csv
# 2024-11-14 16:43:16,174 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_724_1945.html
# 2024-11-14 16:43:16,422 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 724, November 14, 1945 .csv
# 2024-11-14 16:43:16,422 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_723_1945.html
# 2024-11-14 16:43:16,683 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 723, November 03, 1945 .csv
# 2024-11-14 16:43:16,684 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_722_1945.html
# 2024-11-14 16:43:16,959 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 722, November 01, 1945 .csv
# 2024-11-14 16:43:16,959 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_721_1945.html
# 2024-11-14 16:43:17,215 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 721, November 01, 1945 .csv
# 2024-11-14 16:43:17,215 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_720_1945.html
# 2024-11-14 16:43:17,472 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 720, November 01, 1945 .csv
# 2024-11-14 16:43:17,473 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_719_1945.html
# 2024-11-14 16:43:17,738 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 719, November 01, 1945 .csv
# 2024-11-14 16:43:17,739 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_718_1945.html
# 2024-11-14 16:43:18,028 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 718, November 01, 1945 .csv
# 2024-11-14 16:43:18,029 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_717_1945.html
# 2024-11-14 16:43:18,325 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 717, November 01, 1945 .csv
# 2024-11-14 16:43:18,326 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_716_1945.html
# 2024-11-14 16:43:18,590 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 716, November 01, 1945 .csv
# 2024-11-14 16:43:18,591 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_715_1945.html
# 2024-11-14 16:43:18,842 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 715, November 01, 1945 .csv
# 2024-11-14 16:43:18,843 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_714_1945.html
# 2024-11-14 16:43:19,139 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 714, November 01, 1945 .csv
# 2024-11-14 16:43:19,140 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_713_1945.html
# 2024-11-14 16:43:19,386 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 713, November 01, 1945 .csv
# 2024-11-14 16:43:19,387 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_712_1945.html
# 2024-11-14 16:43:19,630 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 712, November 01, 1945 .csv
# 2024-11-14 16:43:19,631 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_711_1945.html
# 2024-11-14 16:43:19,906 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 711, November 01, 1945 .csv
# 2024-11-14 16:43:19,907 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_710_1945.html
# 2024-11-14 16:43:20,183 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 710, November 01, 1945 .csv
# 2024-11-14 16:43:20,184 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_709_1945.html
# 2024-11-14 16:43:20,465 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 709, November 01, 1945 .csv
# 2024-11-14 16:43:20,466 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_708_1945.html
# 2024-11-14 16:43:20,757 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 708, November 01, 1945 .csv
# 2024-11-14 16:43:20,757 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_707_1945.html
# 2024-11-14 16:43:21,068 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 707, November 01, 1945 .csv
# 2024-11-14 16:43:21,069 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_706_1945.html
# 2024-11-14 16:43:21,365 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 706, November 01, 1945 .csv
# 2024-11-14 16:43:21,366 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_705_1945.html
# 2024-11-14 16:43:21,705 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 705, November 01, 1945 .csv
# 2024-11-14 16:43:21,705 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_704_1945.html
# 2024-11-14 16:43:21,972 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 704, November 01, 1945 .csv
# 2024-11-14 16:43:21,973 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_703_1945.html
# 2024-11-14 16:43:22,277 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 703, November 01, 1945 .csv
# 2024-11-14 16:43:22,278 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_702_1945.html
# 2024-11-14 16:43:22,554 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 702, November 01, 1945 .csv
# 2024-11-14 16:43:22,554 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_701_1945.html
# 2024-11-14 16:43:22,890 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 701, November 01, 1945 .csv
# 2024-11-14 16:43:22,891 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_700_1945.html
# 2024-11-14 16:43:23,185 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 700, November 01, 1945 .csv
# 2024-11-14 16:43:23,186 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_699_1945.html
# 2024-11-14 16:43:24,323 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 699, November 20, 1945 .csv
# 2024-11-14 16:43:24,323 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_698_1945.html
# 2024-11-14 16:43:24,749 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 698, October 15, 1945 .csv
# 2024-11-14 16:43:24,750 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_697_1945.html
# 2024-11-14 16:43:25,107 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 697, October 15, 1945 .csv
# 2024-11-14 16:43:25,107 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_696_1945.html
# 2024-11-14 16:43:25,419 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 696, October 15, 1945 .csv
# 2024-11-14 16:43:25,419 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_695_1945.html
# 2024-11-14 16:43:25,683 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 695, October 15, 1945 .csv
# 2024-11-14 16:43:25,684 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_694_1945.html
# 2024-11-14 16:43:25,955 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 694, October 15, 1945 .csv
# 2024-11-14 16:43:25,956 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_693_1945.html
# 2024-11-14 16:43:26,210 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 693, October 15, 1945 .csv
# 2024-11-14 16:43:26,210 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_692_1945.html
# 2024-11-14 16:43:26,606 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 692, October 15, 1945 .csv
# 2024-11-14 16:43:26,607 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_691_1945.html
# 2024-11-14 16:43:26,903 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 691, October 15, 1945 .csv
# 2024-11-14 16:43:26,904 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_690_1945.html
# 2024-11-14 16:43:27,495 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 690, October 15, 1945 .csv
# 2024-11-14 16:43:27,496 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_689_1945.html
# 2024-11-14 16:43:27,783 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 689, October 15, 1945 .csv
# 2024-11-14 16:43:27,783 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_688_1945.html
# 2024-11-14 16:43:28,128 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 688, October 15, 1945 .csv
# 2024-11-14 16:43:28,129 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_687_1945.html
# 2024-11-14 16:43:28,464 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 687, September 26, 1945 .csv
# 2024-11-14 16:43:28,464 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_686_1945.html
# 2024-11-14 16:43:28,786 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 686, September 26, 1945 .csv
# 2024-11-14 16:43:28,787 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_685_1945.html
# 2024-11-14 16:43:29,663 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 685, September 26, 1945 .csv
# 2024-11-14 16:43:29,664 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_684_1945.html
# 2024-11-14 16:43:30,363 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 684, September 26, 1945 .csv
# 2024-11-14 16:43:30,364 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_683_1945.html
# 2024-11-14 16:43:30,683 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 683, September 25, 1945 .csv
# 2024-11-14 16:43:30,684 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_682_1945.html
# 2024-11-14 16:43:31,012 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 682, September 25, 1945 .csv
# 2024-11-14 16:43:31,013 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_681_1945.html
