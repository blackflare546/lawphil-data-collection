# %%
import os
import requests
import logging
import pandas as pd
import re
from bs4 import BeautifulSoup

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger()

# Base URL for linking
base_url = "https://lawphil.net/statutes/acts/"
start_url = "https://lawphil.net/statutes/acts/acts.html"

# Directory to save the data files
data_dir = "Data/Statutes/Acts"
os.makedirs(data_dir, exist_ok=True)

def fetch_page(url):
    """Fetches the HTML content of a given URL."""
    try:
        response = requests.get(url)
        response.raise_for_status()
        return response.text
    except requests.RequestException as e:
        logger.error(f"Failed to fetch page: {url}. Error: {e}")
        return None

def parse_main_page(html):
    """Parses the main page to find the desired table with the list of acts."""
    soup = BeautifulSoup(html, 'html.parser')
    table = soup.find('table', {'id': 's-menu'})
    links = []
    
    if not table:
        logger.error("No table with id 's-menu' found on the page.")
        return links
    
    # Process rows within the table
    for row in table.find_all('tr')[1:]:  # Skip the header row
        columns = row.find_all('td')
        if len(columns) < 2:
            continue

        number_link = columns[0].find('a')
        title = columns[1].text.strip()
        
        if number_link and number_link['href']:
            link = number_link['href']
            # Only append valid links (not javascript or empty)
            if link.startswith("javascript"):
                logger.warning(f"Skipping invalid javascript link: {link}")
                continue
            full_link = base_url + link
            links.append((full_link, title))
    
    logger.info(f"Found {len(links)} valid links in the table.")
    return links

def parse_act_page(url):
    """Parses the act page to retrieve the Number, Title, and Data."""
    html = fetch_page(url)
    if not html:
        return None, None, None

    soup = BeautifulSoup(html, 'html.parser')
    blockquote = soup.find('blockquote')
    if not blockquote:
        logger.warning(f"No blockquote found on page: {url}")
        return None, None, None

    paragraphs = blockquote.find_all('p')
    if len(paragraphs) < 2:
        logger.warning(f"Insufficient paragraphs in blockquote at: {url}")
        return None, None, None

    # Clean the 'Number' by removing square brackets and extra spaces
    number = paragraphs[0].text.strip()
    number = re.sub(r'[\[\]]', '', number)  # Remove square brackets

    title = paragraphs[1].text.strip()
    data = blockquote.text.strip()
    
    return number, title, data

def save_to_csv(number, title, data):
    """Saves the act information to a CSV file in the data directory."""
    file_path = os.path.join(data_dir, f"{number}.csv")
    df = pd.DataFrame([[number, title, data]], columns=["Number", "Title", "Data"])
    df.to_csv(file_path, index=False, encoding='utf-8')
    logger.info(f"Data saved to {file_path}")

def main():
    logger.info("Process started...")  # Log when the process starts

    main_page_html = fetch_page(start_url)
    if not main_page_html:
        logger.error("Failed to retrieve main page.")
        return

    act_links = parse_main_page(main_page_html)
    for url, title in act_links:
        logger.info(f"Processing URL: {url}")
        number, title, data = parse_act_page(url)
        if number and title and data:
            save_to_csv(number, title, data)
        else:
            logger.warning(f"Skipping due to incomplete data for URL: {url}")
    
    logger.info("Process completed!")  # Log when the process is done

if __name__ == "__main__":
    main()
# Out:
# 2024-11-14 17:11:10,576 - INFO - Process started...
# 2024-11-14 17:11:13,544 - WARNING - Skipping invalid javascript link: javascript:history.back(1)
# 2024-11-14 17:11:13,544 - INFO - Found 4333 valid links in the table.
# 2024-11-14 17:11:13,544 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4275_1935.html
# 2024-11-14 17:11:13,838 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4275, November 14, 1935 .csv
# 2024-11-14 17:11:13,839 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4274_1935.html
# 2024-11-14 17:11:14,122 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4274, November 14, 1935 .csv
# 2024-11-14 17:11:14,122 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4273_1935.html
# 2024-11-14 17:11:14,396 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4273, November 14, 1935 .csv
# 2024-11-14 17:11:14,396 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4272_1935.html
# 2024-11-14 17:11:14,739 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4272, November 14, 1935 .csv
# 2024-11-14 17:11:14,740 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4271_1935.html
# 2024-11-14 17:11:15,045 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4271, November 14, 1935 .csv
# 2024-11-14 17:11:15,046 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4270_1935.html
# 2024-11-14 17:11:16,228 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4270, November 14, 1935 .csv
# 2024-11-14 17:11:16,228 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4269_1935.html
# 2024-11-14 17:11:16,735 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4269, November 08, 1935 .csv
# 2024-11-14 17:11:16,736 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4268_1935.html
# 2024-11-14 17:11:17,136 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4268, November 08, 1935 .csv
# 2024-11-14 17:11:17,136 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4267_1935.html
# 2024-11-14 17:11:17,709 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4267, November 07, 1935 .csv
# 2024-11-14 17:11:17,710 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4266_1935.html
# 2024-11-14 17:11:18,862 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4266, November 07, 1935 .csv
# 2024-11-14 17:11:18,863 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4265_1935.html
# 2024-11-14 17:11:19,151 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4265, November 07, 1935 .csv
# 2024-11-14 17:11:19,151 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4264_1935.html
# 2024-11-14 17:11:19,711 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4264, November 07, 1935 .csv
# 2024-11-14 17:11:19,712 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4263_1935.html
# 2024-11-14 17:11:19,977 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4263, November 07, 1935 .csv
# 2024-11-14 17:11:19,978 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4262_1935.html
# 2024-11-14 17:11:20,252 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4262, November 07, 1935 .csv
# 2024-11-14 17:11:20,252 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4261_1935.html
# 2024-11-14 17:11:20,661 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4261, November 07, 1935 .csv
# 2024-11-14 17:11:20,662 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4260_1935.html
# 2024-11-14 17:11:20,910 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4260, November 06, 1935 .csv
# 2024-11-14 17:11:20,910 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4259_1935.html
# 2024-11-14 17:11:21,155 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4259, November 06, 1935 .csv
# 2024-11-14 17:11:21,156 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4258_1935.html
# 2024-11-14 17:11:21,417 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4258, November 06, 1935 .csv
# 2024-11-14 17:11:21,418 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4257_1935.html
# 2024-11-14 17:11:21,655 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4257, November 06, 1935 .csv
# 2024-11-14 17:11:21,656 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4256_1935.html
# 2024-11-14 17:11:21,918 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4256, November 06, 1935 .csv
# 2024-11-14 17:11:21,919 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4255_1935.html
# 2024-11-14 17:11:22,165 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4255, November 06, 1935 .csv
# 2024-11-14 17:11:22,166 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4254_1935.html
# 2024-11-14 17:11:22,420 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4254, November 06, 1935 .csv
# 2024-11-14 17:11:22,421 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4253_1935.html
# 2024-11-14 17:11:22,670 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4253, November 06, 1935 .csv
# 2024-11-14 17:11:22,671 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4252_1935.html
# 2024-11-14 17:11:22,919 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4252, November 06, 1935 .csv
# 2024-11-14 17:11:22,920 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4251_1935.html
# 2024-11-14 17:11:23,185 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4251, November 06, 1935 .csv
# 2024-11-14 17:11:23,185 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4250_1935.html
# 2024-11-14 17:11:23,433 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4250, November 06, 1935 .csv
# 2024-11-14 17:11:23,434 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4249_1935.html
# 2024-11-14 17:11:23,735 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4249, November 06, 1935 .csv
# 2024-11-14 17:11:23,736 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4248_1935.html
# 2024-11-14 17:11:24,052 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4248, October 31, 1935 .csv
# 2024-11-14 17:11:24,053 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4247_1935.html
# 2024-11-14 17:11:24,300 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4247, October 28, 1935 .csv
# 2024-11-14 17:11:24,300 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4246_1935.html
# 2024-11-14 17:11:24,554 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4246, October 28, 1935 .csv
# 2024-11-14 17:11:24,555 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4245_1935.html
# 2024-11-14 17:11:24,819 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4245, October 14, 1935 .csv
# 2024-11-14 17:11:24,819 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4244_1935.html
# 2024-11-14 17:11:25,142 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4244, October 10, 1935 .csv
# 2024-11-14 17:11:25,142 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4243_1935.html
# 2024-11-14 17:11:25,407 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4243, September 21, 1935 .csv
# 2024-11-14 17:11:25,408 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4242_1935.html
# 2024-11-14 17:11:25,808 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4242, August 26, 1935 .csv
# 2024-11-14 17:11:25,809 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4241_1935.html
# 2024-11-14 17:11:26,108 - INFO - Data saved to Data/Statutes/Acts/ Act No. 4241, August 23, 1935 .csv
# 2024-11-14 17:11:26,108 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4240_1935.html
# 2024-11-14 17:11:26,392 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4240, August 22, 1935 .csv
# 2024-11-14 17:11:26,393 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4239_1935.html
# 2024-11-14 17:11:26,633 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4239, August 22, 1935 .csv
# 2024-11-14 17:11:26,634 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4238_1935.html
# 2024-11-14 17:11:26,879 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4238, August 21, 1935 .csv
# 2024-11-14 17:11:26,880 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4237_1935.html
# 2024-11-14 17:11:27,132 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4237, August 20, 1935 .csv
# 2024-11-14 17:11:27,132 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4236_1935.html
# 2024-11-14 17:11:27,380 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4236, August 20, 1935 .csv
# 2024-11-14 17:11:27,380 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4235_1935.html
# 2024-11-14 17:11:27,631 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4235, August 20, 1935 .csv
# 2024-11-14 17:11:27,632 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4234_1935.html
# 2024-11-14 17:11:27,896 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4234, August 16, 1935 .csv
# 2024-11-14 17:11:27,896 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4233_1935.html
# 2024-11-14 17:11:28,154 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4233, August 16, 1935 .csv
# 2024-11-14 17:11:28,154 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4232_1935.html
# 2024-11-14 17:11:28,440 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4232, August 16, 1935 .csv
# 2024-11-14 17:11:28,440 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4231_1935.html
# 2024-11-14 17:11:28,778 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4231, August 16, 1935 .csv
# 2024-11-14 17:11:28,778 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4230_1935.html
# 2024-11-14 17:11:29,030 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4230, August 16, 1935 .csv
# 2024-11-14 17:11:29,031 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4229_1935.html
# 2024-11-14 17:11:29,329 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4229, August 12, 1935 .csv
# 2024-11-14 17:11:29,330 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4228_1935.html
# 2024-11-14 17:11:29,585 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4228, August 10, 1935 .csv
# 2024-11-14 17:11:29,586 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4227_1935.html
# 2024-11-14 17:11:29,829 - INFO - Data saved to Data/Statutes/Acts/ Acts No. 4227, August 09, 1935 .csv
# 2024-11-14 17:11:29,830 - INFO - Processing URL: https://lawphil.net/statutes/acts/act1935/act_4226_1935.html
