# %%
import os
import requests
import logging
import pandas as pd
import re
from bs4 import BeautifulSoup

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger()

# Base URL for linking
base_url = "https://lawphil.net/statutes/comacts/"
start_url = "https://lawphil.net/statutes/comacts/comacts.html"

# Directory to save the data files
data_dir = "Data/Statutes/Common Wealth Acts"
os.makedirs(data_dir, exist_ok=True)

def fetch_page(url):
    """Fetches the HTML content of a given URL."""
    try:
        response = requests.get(url)
        response.raise_for_status()
        return response.text
    except requests.RequestException as e:
        logger.error(f"Failed to fetch page: {url}. Error: {e}")
        return None

def parse_main_page(html):
    """Parses the main page to find the desired table with the list of acts."""
    soup = BeautifulSoup(html, 'html.parser')
    table = soup.find('table', {'id': 's-menu'})
    links = []
    
    if not table:
        logger.error("No table with id 's-menu' found on the page.")
        return links
    
    # Process rows within the table
    for row in table.find_all('tr')[1:]:  # Skip the header row
        columns = row.find_all('td')
        if len(columns) < 2:
            continue

        number_link = columns[0].find('a')
        title = columns[1].text.strip()
        
        if number_link and number_link['href']:
            full_link = base_url + number_link['href']
            links.append((full_link, title))
    
    logger.info(f"Found {len(links)} links in the table.")
    return links

def parse_act_page(url):
    """Parses the act page to retrieve the Number, Title, and Data."""
    html = fetch_page(url)
    if not html:
        return None, None, None

    soup = BeautifulSoup(html, 'html.parser')
    blockquote = soup.find('blockquote')
    if not blockquote:
        logger.warning(f"No blockquote found on page: {url}")
        return None, None, None

    paragraphs = blockquote.find_all('p')
    if len(paragraphs) < 2:
        logger.warning(f"Insufficient paragraphs in blockquote at: {url}")
        return None, None, None

    # Clean the 'Number' by removing square brackets and extra spaces
    number = paragraphs[0].text.strip()
    number = re.sub(r'[\[\]]', '', number)  # Remove square brackets

    title = paragraphs[1].text.strip()
    data = blockquote.text.strip()
    
    return number, title, data

def save_to_csv(number, title, data):
    """Saves the act information to a CSV file in the data directory."""
    file_path = os.path.join(data_dir, f"{number}.csv")
    df = pd.DataFrame([[number, title, data]], columns=["Number", "Title", "Data"])
    df.to_csv(file_path, index=False, encoding='utf-8')
    logger.info(f"Data saved to {file_path}")

def main():
    main_page_html = fetch_page(start_url)
    if not main_page_html:
        logger.error("Failed to retrieve main page.")
        return

    act_links = parse_main_page(main_page_html)
    for url, title in act_links:
        logger.info(f"Processing URL: {url}")
        number, title, data = parse_act_page(url)
        if number and title and data:
            save_to_csv(number, title, data)
        else:
            logger.warning(f"Skipping due to incomplete data for URL: {url}")

if __name__ == "__main__":
    main()
# Out:
# 2024-11-14 16:16:56,220 - INFO - Found 734 links in the table.
# 2024-11-14 16:16:56,220 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1946/ca_733_1946.html
# 2024-11-14 16:17:01,061 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 733, July 03, 1946 .csv
# 2024-11-14 16:17:01,062 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1946/ca_732_1946.html
# 2024-11-14 16:17:04,897 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 732, July 03, 1946 .csv
# 2024-11-14 16:17:04,898 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1946/ca_731_1946.html
# 2024-11-14 16:17:09,303 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 731, July 03, 1946 .csv
# 2024-11-14 16:17:09,304 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1946/ca_730_1946.html
# 2024-11-14 16:17:13,708 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 730, July 02, 1946 .csv
# 2024-11-14 16:17:13,709 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1946/ca_729_1946.html
# 2024-11-14 16:17:18,282 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 729, July 02, 1946 .csv
# 2024-11-14 16:17:18,283 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1946/ca_728_1946.html
# 2024-11-14 16:17:21,889 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 728, July 02, 1946 .csv
# 2024-11-14 16:17:21,891 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1946/ca_727_1946.html
# 2024-11-14 16:17:26,304 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 727, January 18, 1946 .csv
# 2024-11-14 16:17:26,305 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1946/ca_726_1946.html
# 2024-11-14 16:17:29,470 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 726, January 15, 1946 .csv
# 2024-11-14 16:17:29,471 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1946/ca_725_1946.html
# 2024-11-14 16:17:32,456 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 725, January 05, 1946 .csv
# 2024-11-14 16:17:32,457 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_724_1945.html
# 2024-11-14 16:17:34,794 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 724, November 14, 1945 .csv
# 2024-11-14 16:17:34,795 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_723_1945.html
# 2024-11-14 16:17:37,771 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 723, November 03, 1945 .csv
# 2024-11-14 16:17:37,771 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_722_1945.html
# 2024-11-14 16:17:40,256 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 722, November 01, 1945 .csv
# 2024-11-14 16:17:40,257 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_721_1945.html
# 2024-11-14 16:17:42,942 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 721, November 01, 1945 .csv
# 2024-11-14 16:17:42,943 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_720_1945.html
# 2024-11-14 16:17:45,745 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 720, November 01, 1945 .csv
# 2024-11-14 16:17:45,746 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_719_1945.html
# 2024-11-14 16:17:47,899 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 719, November 01, 1945 .csv
# 2024-11-14 16:17:47,900 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_718_1945.html
# 2024-11-14 16:17:52,063 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 718, November 01, 1945 .csv
# 2024-11-14 16:17:52,064 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_717_1945.html
# 2024-11-14 16:17:56,354 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 717, November 01, 1945 .csv
# 2024-11-14 16:17:56,355 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_716_1945.html
# 2024-11-14 16:18:02,149 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 716, November 01, 1945 .csv
# 2024-11-14 16:18:02,151 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_715_1945.html
# 2024-11-14 16:18:09,209 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 715, November 01, 1945 .csv
# 2024-11-14 16:18:09,210 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_714_1945.html
# 2024-11-14 16:18:14,830 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 714, November 01, 1945 .csv
# 2024-11-14 16:18:14,831 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_713_1945.html
# 2024-11-14 16:18:19,149 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 713, November 01, 1945 .csv
# 2024-11-14 16:18:19,149 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_712_1945.html
# 2024-11-14 16:18:23,690 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 712, November 01, 1945 .csv
# 2024-11-14 16:18:23,691 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_711_1945.html
# 2024-11-14 16:18:30,140 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 711, November 01, 1945 .csv
# 2024-11-14 16:18:30,141 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_710_1945.html
# 2024-11-14 16:18:36,638 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 710, November 01, 1945 .csv
# 2024-11-14 16:18:36,639 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_709_1945.html
# 2024-11-14 16:18:41,365 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 709, November 01, 1945 .csv
# 2024-11-14 16:18:41,366 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_708_1945.html
# 2024-11-14 16:18:46,040 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 708, November 01, 1945 .csv
# 2024-11-14 16:18:46,041 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_707_1945.html
# 2024-11-14 16:18:51,799 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 707, November 01, 1945 .csv
# 2024-11-14 16:18:51,800 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_706_1945.html
# 2024-11-14 16:18:56,813 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 706, November 01, 1945 .csv
# 2024-11-14 16:18:56,814 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_705_1945.html
# 2024-11-14 16:19:02,336 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 705, November 01, 1945 .csv
# 2024-11-14 16:19:02,337 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_704_1945.html
# 2024-11-14 16:19:08,081 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 704, November 01, 1945 .csv
# 2024-11-14 16:19:08,082 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_703_1945.html
# 2024-11-14 16:19:13,099 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 703, November 01, 1945 .csv
# 2024-11-14 16:19:13,099 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_702_1945.html
# 2024-11-14 16:19:17,545 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 702, November 01, 1945 .csv
# 2024-11-14 16:19:17,546 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_701_1945.html
# 2024-11-14 16:19:21,671 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 701, November 01, 1945 .csv
# 2024-11-14 16:19:21,672 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_700_1945.html
# 2024-11-14 16:19:28,350 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 700, November 01, 1945 .csv
# 2024-11-14 16:19:28,351 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_699_1945.html
# 2024-11-14 16:19:33,877 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 699, November 20, 1945 .csv
# 2024-11-14 16:19:33,878 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_698_1945.html
# 2024-11-14 16:19:44,664 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 698, October 15, 1945 .csv
# 2024-11-14 16:19:44,664 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_697_1945.html
# 2024-11-14 16:20:25,126 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 697, October 15, 1945 .csv
# 2024-11-14 16:20:25,126 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_696_1945.html
# 2024-11-14 16:20:29,527 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 696, October 15, 1945 .csv
# 2024-11-14 16:20:29,528 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_695_1945.html
# 2024-11-14 16:20:35,975 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 695, October 15, 1945 .csv
# 2024-11-14 16:20:35,976 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_694_1945.html
# 2024-11-14 16:20:43,744 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 694, October 15, 1945 .csv
# 2024-11-14 16:20:43,745 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_693_1945.html
# 2024-11-14 16:20:49,162 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 693, October 15, 1945 .csv
# 2024-11-14 16:20:49,164 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_692_1945.html
# 2024-11-14 16:20:58,709 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 692, October 15, 1945 .csv
# 2024-11-14 16:20:58,710 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_691_1945.html
# 2024-11-14 16:21:06,389 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 691, October 15, 1945 .csv
# 2024-11-14 16:21:06,390 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_690_1945.html
# 2024-11-14 16:21:24,902 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 690, October 15, 1945 .csv
# 2024-11-14 16:21:24,903 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_689_1945.html
# 2024-11-14 16:21:29,874 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 689, October 15, 1945 .csv
# 2024-11-14 16:21:29,875 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_688_1945.html
# 2024-11-14 16:21:35,749 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 688, October 15, 1945 .csv
# 2024-11-14 16:21:35,750 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_687_1945.html
# 2024-11-14 16:21:42,464 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 687, September 26, 1945 .csv
# 2024-11-14 16:21:42,465 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_686_1945.html
# 2024-11-14 16:21:47,464 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 686, September 26, 1945 .csv
# 2024-11-14 16:21:47,465 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_685_1945.html
# 2024-11-14 16:21:57,234 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 685, September 26, 1945 .csv
# 2024-11-14 16:21:57,235 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_684_1945.html
# 2024-11-14 16:22:03,154 - INFO - Data saved to Data/Statutes/Common Wealth Acts/ Commonwealth Act No. 684, September 26, 1945 .csv
# 2024-11-14 16:22:03,155 - INFO - Processing URL: https://lawphil.net/statutes/comacts/ca1945/ca_683_1945.html
